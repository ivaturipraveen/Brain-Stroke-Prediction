# %%
#Step -1
#importing the libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as s
# %matplotlib inline
import pandasql as ps

# Set to display all the columns of the dataset
pd.set_option("display.max_columns",None)

#Ignore harmless warnings
import warnings
warnings.filterwarnings("ignore")

# %%
#Step -2
#Load the data
bsdata=pd.read_csv(r"C:\Users\Praveen\Desktop\INTERNSHIP 26-07\PROJECT\full_data.csv",header=0)
#Step -3
#Copy to back_up file
bsdata_bk=bsdata.copy()
#Display first 5 records
bsdata.head()
# Out:
#    gender   age  hypertension  heart_disease ever_married      work_type  \
# 0    Male  67.0             0              1          Yes        Private
# 1    Male  80.0             0              1          Yes        Private
# 2  Female  49.0             0              0          Yes        Private
# 3  Female  79.0             1              0          Yes  Self-employed
# 4    Male  81.0             0              0          Yes        Private
#
#   Residence_type  avg_glucose_level   bmi   smoking_status  stroke
# 0          Urban             228.69  36.6  formerly smoked       1
# 1          Rural             105.92  32.5     never smoked       1
# 2          Urban             171.23  34.4           smokes       1
# 3          Rural             174.12  24.0     never smoked       1
# 4          Urban             186.21  29.0  formerly smoked       1

# %%
#Step -4
#Display the data set information
bsdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4981 entries, 0 to 4980
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   gender             4981 non-null   object
#  1   age                4981 non-null   float64
#  2   hypertension       4981 non-null   int64
#  3   heart_disease      4981 non-null   int64
#  4   ever_married       4981 non-null   object
#  5   work_type          4981 non-null   object
#  6   Residence_type     4981 non-null   object
#  7   avg_glucose_level  4981 non-null   float64
#  8   bmi                4981 non-null   float64
#  9   smoking_status     4981 non-null   object
#  10  stroke             4981 non-null   int64
# dtypes: float64(3), int64(3), object(5)
# memory usage: 428.2+ KB

# %%
# Count the target or dependent variable by '0' & '1' and their proportion 
# (>= 10 : 1, then the dataset is imbalance data)

stroke_count = bsdata.stroke.value_counts()
print("proportion: ",stroke_count[0]/stroke_count[1],":1")
# Out:
# proportion:  19.08467741935484 :1

# %%
#Step -5
#Display the unique values of the data set
bsdata.nunique()
# Out:
# gender                  2
# age                   104
# hypertension            2
# heart_disease           2
# ever_married            2
# work_type               4
# Residence_type          2
# avg_glucose_level    3895
# bmi                   342
# smoking_status          4
# stroke                  2
# dtype: int64

# %%
# Count the missig values by each variable, if available
bsdata.isnull().sum()
# Out:
# gender               0
# age                  0
# hypertension         0
# heart_disease        0
# ever_married         0
# work_type            0
# Residence_type       0
# avg_glucose_level    0
# bmi                  0
# smoking_status       0
# stroke               0
# dtype: int64

# %%
#Step -6
#Check the duplicate  values with in  dataset if available
bsdata_dup=bsdata[bsdata.duplicated(keep='last')]
bsdata_dup
# Out:
# Empty DataFrame
# Columns: [gender, age, hypertension, heart_disease, ever_married, work_type, Residence_type, avg_glucose_level, bmi, smoking_status, stroke]
# Index: []

# %%
'''
Based on  analysis:-

1) ## Females are more likely to get a stroke than male.
2) ### People who are employed in the private sector are more likely to get a stroke.
3) There is no clear relation between heart diseases and hypertension with stroke.
4) Smoking is not a conclusive evidence to determine stroke.
5) ### People who are obese,overweight are more likely to get a stroke.
6) ## People with low glucose level are likely to get a stroke.
7) ## Senior and super senior citizens are more likely to get a stroke.
8) Marriage doesn't determine stroke.

'''
# Out:
# "\nBased on  analysis:-\n\n1) ## Females are more likely to get a stroke than male.\n2) ### People who are employed in the private sector are more likely to get a stroke.\n3) There is no clear relation between heart diseases and hypertension with stroke.\n4) Smoking is not a conclusive evidence to determine stroke.\n5) ### People who are obese,overweight are more likely to get a stroke.\n6) ## People with low glucose level are likely to get a stroke.\n7) ## Senior and super senior citizens are more likely to get a stroke.\n8) Marriage doesn't determine stroke.\n\n"

# %%
#bsdata= bsdata.drop(['gender','ever_married','work_type','Residence_type'],axis=1)
#bsdata.head()

# %%
#Display the unique values by count for 'gender'
bsdata['gender'].value_counts()
# Out:
# Female    2907
# Male      2074
# Name: gender, dtype: int64

# %%
#Display the unique values by count for 'work_type'
bsdata['work_type'].value_counts()
# Out:
# Private          2860
# Self-employed     804
# children          673
# Govt_job          644
# Name: work_type, dtype: int64

# %%
#Display the unique values by count for 'ever_married'
bsdata['ever_married'].value_counts()
# Out:
# Yes    3280
# No     1701
# Name: ever_married, dtype: int64

# %%
#Display the unique values by count for 'Residence_type'
bsdata['Residence_type'].value_counts()
# Out:
# Urban    2532
# Rural    2449
# Name: Residence_type, dtype: int64

# %%
#Display the unique values by count for 'smoking_status'
bsdata['smoking_status'].value_counts()
# Out:
# never smoked       1838
# Unknown            1500
# formerly smoked     867
# smokes              776
# Name: smoking_status, dtype: int64

# %%
#Step -8,9
#use LabelEncoder for target variable
object_col = ["gender", "ever_married", "Residence_type","smoking_status","work_type"]
from sklearn.preprocessing import LabelEncoder
LE = LabelEncoder()
for col in object_col:
    bsdata[col] = LE.fit_transform(bsdata[col])

# %%
bsdata['gender'].value_counts()
# Out:
# 0    2907
# 1    2074
# Name: gender, dtype: int64

# %%
bsdata['ever_married'].value_counts()
# Out:
# 1    3280
# 0    1701
# Name: ever_married, dtype: int64

# %%
bsdata['Residence_type'].value_counts()
# Out:
# 1    2532
# 0    2449
# Name: Residence_type, dtype: int64

# %%
bsdata['smoking_status'].value_counts()
# Out:
# 2    1838
# 0    1500
# 1     867
# 3     776
# Name: smoking_status, dtype: int64

# %%
bsdata['work_type'].value_counts()
# Out:
# 1    2860
# 2     804
# 3     673
# 0     644
# Name: work_type, dtype: int64

# %%
#Display the data set information
bsdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4981 entries, 0 to 4980
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   gender             4981 non-null   int32
#  1   age                4981 non-null   float64
#  2   hypertension       4981 non-null   int64
#  3   heart_disease      4981 non-null   int64
#  4   ever_married       4981 non-null   int32
#  5   work_type          4981 non-null   int32
#  6   Residence_type     4981 non-null   int32
#  7   avg_glucose_level  4981 non-null   float64
#  8   bmi                4981 non-null   float64
#  9   smoking_status     4981 non-null   int32
#  10  stroke             4981 non-null   int64
# dtypes: float64(3), int32(5), int64(3)
# memory usage: 330.9 KB

# %%
bsdata.head()
# Out:
#    gender   age  hypertension  heart_disease  ever_married  work_type  \
# 0       1  67.0             0              1             1          1
# 1       1  80.0             0              1             1          1
# 2       0  49.0             0              0             1          1
# 3       0  79.0             1              0             1          2
# 4       1  81.0             0              0             1          1
#
#    Residence_type  avg_glucose_level   bmi  smoking_status  stroke
# 0               1             228.69  36.6               1       1
# 1               0             105.92  32.5               2       1
# 2               1             171.23  34.4               3       1
# 3               0             174.12  24.0               2       1
# 4               1             186.21  29.0               1       1

# %%
# Display descriptive statistics
bsdata.describe()
# Out:
#             gender          age  hypertension  heart_disease  ever_married  \
# count  4981.000000  4981.000000   4981.000000    4981.000000   4981.000000
# mean      0.416382    43.419859      0.096165       0.055210      0.658502
# std       0.493008    22.662755      0.294848       0.228412      0.474260
# min       0.000000     0.080000      0.000000       0.000000      0.000000
# 25%       0.000000    25.000000      0.000000       0.000000      0.000000
# 50%       0.000000    45.000000      0.000000       0.000000      1.000000
# 75%       1.000000    61.000000      0.000000       0.000000      1.000000
# max       1.000000    82.000000      1.000000       1.000000      1.000000
#
#          work_type  Residence_type  avg_glucose_level          bmi  \
# count  4981.000000     4981.000000        4981.000000  4981.000000
# mean      1.302349        0.508332         105.943562    28.498173
# std       0.860170        0.499981          45.075373     6.790464
# min       0.000000        0.000000          55.120000    14.000000
# 25%       1.000000        0.000000          77.230000    23.700000
# 50%       1.000000        1.000000          91.850000    28.100000
# 75%       2.000000        1.000000         113.860000    32.600000
# max       3.000000        1.000000         271.740000    48.900000
#
#        smoking_status       stroke
# count     4981.000000  4981.000000
# mean         1.379442     0.049789
# std          1.072180     0.217531
# min          0.000000     0.000000
# 25%          0.000000     0.000000
# 50%          2.000000     0.000000
# 75%          2.000000     0.000000
# max          3.000000     1.000000

# %%
#Identify the variables to normalize with minmaxscalar
cols=['age','gender','hypertension','ever_married','heart_disease','work_type','Residence_type','avg_glucose_level','bmi','smoking_status']

# %%
#Step -10
# identify the Independent and Target (dependent variables)
IndepVar = []
for col in bsdata.columns:
    if col != 'stroke':
        IndepVar.append(col)
TargetVar = 'stroke'
x = bsdata[IndepVar]
y = bsdata[TargetVar]

# %%
#Step -11
# Split the data into train and test (random splitting)

from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.3,random_state = 42)

# Display the shape for train and test data

x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((3486, 10), (1495, 10), (3486,), (1495,))

# %%
stroke_count = bsdata.stroke.value_counts()
print("proportion: ",stroke_count[0]/stroke_count[1],":1")
# Out:
# proportion:  19.08467741935484 :1

# %%
#Step -12
# Scaling the features by using MinMaxScaler

from sklearn.preprocessing import MinMaxScaler

mmscaler = MinMaxScaler(feature_range=(0, 1))

x_train[cols] = mmscaler.fit_transform(x_train[cols])
x_train = pd.DataFrame(x_train)

x_test[cols] = mmscaler.fit_transform(x_test[cols])
x_test = pd.DataFrame(x_test)

# %%
from imblearn.over_sampling import RandomOverSampler
from imblearn.under_sampling import RandomUnderSampler

# Perform Oversampling
oversampler = RandomOverSampler(sampling_strategy='auto', random_state=42)
x_train_resampled, y_train_resampled = oversampler.fit_resample(x_train, y_train)

# Perform Undersampling
undersampler = RandomUnderSampler(sampling_strategy='auto', random_state=42)
x_train_resampled, y_train_resampled = undersampler.fit_resample(x_train_resampled, y_train_resampled)

# Count the target variable by '0' & '1' and their proportion after resampling
stroke_count_resampled = y_train_resampled.value_counts()
print("Proportion after resampling: ", stroke_count_resampled[0] / stroke_count_resampled[1], ":1")
# Out:
# Proportion after resampling:  1.0 :1

# %% [markdown]
# # SVM- Linear Kernel

# %%
# Training the SVM algorithm with train dataset

from sklearn.svm import SVC

ModelSVM1 = SVC(C=1.0, kernel='linear', degree=3, gamma='scale', coef0=0.0, shrinking=True, 
                probability=True, tol=0.001, cache_size=200, class_weight=None, verbose=False, 
                max_iter=- 1, decision_function_shape='ovr', break_ties=False, random_state=None)

# Train the model using balanced data 
ModelSVM1 = ModelSVM1.fit(x_train_resampled, y_train_resampled)


# Predict the model with test data set

y_pred = ModelSVM1.predict(x_test)
y_pred_prob = ModelSVM1.predict_proba(x_test)

# Print the model name
    
print('Model Name: ', "SVM - Linear")

# Confusion matrix in sklearn

from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# actual values

actual = y_test

# predicted values

predicted = y_pred

# confusion matrix

matrix = confusion_matrix(actual,predicted, labels=[1,0],sample_weight=None, normalize=None)
print('Confusion matrix : \n', matrix)

# outcome values order in sklearn

tp, fn, fp, tn = confusion_matrix(actual,predicted,labels=[1,0]).reshape(-1)
print('Outcome values : \n', tp, fn, fp, tn)

# classification report for precision, recall f1-score and accuracy

C_Report = classification_report(actual,predicted,labels=[1,0])

print('Classification report : \n', C_Report)

# calculating the metrics

sensitivity = round(tp/(tp+fn), 3);
specificity = round(tn/(tn+fp), 3);
accuracy = round((tp+tn)/(tp+fp+tn+fn), 3);
balanced_accuracy = round((sensitivity+specificity)/2, 3);
precision = round(tp/(tp+fp), 3);
f1Score = round((2*tp/(2*tp + fp + fn)), 3);

# Matthews Correlation Coefficient (MCC). Range of values of MCC lie between -1 to +1. 
# A model with a score of +1 is a perfect model and -1 is a poor model

from math import sqrt

mx = (tp+fp) * (tp+fn) * (tn+fp) * (tn+fn)
MCC = round(((tp * tn) - (fp * fn)) / sqrt(mx), 3)

print('Accuracy :', round(accuracy*100, 2),'%')
print('Precision :', round(precision*100, 2),'%')
print('Recall :', round(sensitivity*100,2), '%')
print('F1 Score :', f1Score)
print('Specificity or True Negative Rate :', round(specificity*100,2), '%'  )
print('Balanced Accuracy :', round(balanced_accuracy*100, 2),'%')
print('MCC :', MCC)

# Area under ROC curve 

from sklearn.metrics import roc_curve, roc_auc_score

print('roc_auc_score:', round(roc_auc_score(actual, predicted), 3))

# ROC Curve

from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
model_roc_auc = roc_auc_score(actual, predicted)
fpr, tpr, thresholds = roc_curve(actual,ModelSVM1.predict_proba(x_test)[:,1])
plt.figure()
# plt.plot(fpr, tpr, label='Logistic Regression (area = %0.2f)' % logit_roc_auc)
plt.plot(fpr, tpr, label= 'Classification Model' % model_roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.savefig('Log_ROC')
plt.show()
# Out:
# Model Name:  SVM - Linear
# Confusion matrix :
#  [[  62   16]
#  [ 374 1043]]
# Outcome values :
#  62 16 374 1043
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.14      0.79      0.24        78
#            0       0.98      0.74      0.84      1417
#
#     accuracy                           0.74      1495
#    macro avg       0.56      0.77      0.54      1495
# weighted avg       0.94      0.74      0.81      1495
#
# Accuracy : 73.9 %
# Precision : 14.2 %
# Recall : 79.5 %
# F1 Score : 0.241
# Specificity or True Negative Rate : 73.6 %
# Balanced Accuracy : 76.6 %
# MCC : 0.26
# roc_auc_score: 0.765

# %% [markdown]
# # Polynomial Kernel

# %%
# Training the SVM algorithm

from sklearn.svm import SVC

ModelSVMPoly = SVC(kernel='poly', degree=2, probability=True)

# Train the model using balanced data 

ModelSVMPoly.fit(x_train_resampled, y_train_resampled)

# Predict the model with test data set

y_pred = ModelSVMPoly.predict(x_test)
y_pred_prob = ModelSVMPoly.predict_proba(x_test)

# Print the model name
    
print('Model Name: ', "SVM - Polynominal")

# Confusion matrix in sklearn

from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# actual values

actual = y_test

# predicted values

predicted = y_pred

# confusion matrix

matrix = confusion_matrix(actual,predicted, labels=[1,0],sample_weight=None, normalize=None)
print('Confusion matrix : \n', matrix)

# outcome values order in sklearn

tp, fn, fp, tn = confusion_matrix(actual,predicted,labels=[1,0]).reshape(-1)
print('Outcome values : \n', tp, fn, fp, tn)

# classification report for precision, recall f1-score and accuracy

C_Report = classification_report(actual,predicted,labels=[1,0])

print('Classification report : \n', C_Report)

# calculating the metrics

sensitivity = round(tp/(tp+fn), 3);
specificity = round(tn/(tn+fp), 3);
accuracy = round((tp+tn)/(tp+fp+tn+fn), 3);
balanced_accuracy = round((sensitivity+specificity)/2, 3);
precision = round(tp/(tp+fp), 3);
f1Score = round((2*tp/(2*tp + fp + fn)), 3);

# Matthews Correlation Coefficient (MCC). Range of values of MCC lie between -1 to +1. 
# A model with a score of +1 is a perfect model and -1 is a poor model

from math import sqrt

mx = (tp+fp) * (tp+fn) * (tn+fp) * (tn+fn)
MCC = round(((tp * tn) - (fp * fn)) / sqrt(mx), 3)

print('Accuracy :', round(accuracy*100, 2),'%')
print('Precision :', round(precision*100, 2),'%')
print('Recall :', round(sensitivity*100,2), '%')
print('F1 Score :', f1Score)
print('Specificity or True Negative Rate :', round(specificity*100,2), '%'  )
print('Balanced Accuracy :', round(balanced_accuracy*100, 2),'%')
print('MCC :', MCC)

# Area under ROC curve 

from sklearn.metrics import roc_curve, roc_auc_score

print('roc_auc_score:', round(roc_auc_score(y_test, y_pred), 3))

# ROC Curve

from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
logit_roc_auc = roc_auc_score(y_test, y_pred)
fpr, tpr, thresholds = roc_curve(y_test,ModelSVMPoly.predict_proba(x_test)[:,1])
plt.figure()
# plt.plot
plt.plot(fpr, tpr, label= 'Classification Model' % logit_roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.savefig('Log_ROC')
plt.show()
# Out:
# Model Name:  SVM - Polynominal
# Confusion matrix :
#  [[  55   23]
#  [ 358 1059]]
# Outcome values :
#  55 23 358 1059
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.13      0.71      0.22        78
#            0       0.98      0.75      0.85      1417
#
#     accuracy                           0.75      1495
#    macro avg       0.56      0.73      0.54      1495
# weighted avg       0.93      0.75      0.82      1495
#
# Accuracy : 74.5 %
# Precision : 13.3 %
# Recall : 70.5 %
# F1 Score : 0.224
# Specificity or True Negative Rate : 74.7 %
# Balanced Accuracy : 72.6 %
# MCC : 0.225
# roc_auc_score: 0.726

# %% [markdown]
# # Gaussian Kernel

# %%
# Training the SVM algorithm

from sklearn.svm import SVC

ModelSVMGaussian = SVC(kernel='rbf', random_state = 42, class_weight='balanced', probability=True)

# Train the model using balanced data 

ModelSVMGaussian.fit(x_train_resampled, y_train_resampled)

# Predict the model with test data set

y_pred = ModelSVMGaussian.predict(x_test)
y_pred_prob = ModelSVMGaussian.predict_proba(x_test)

# Confusion matrix in sklearn

from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# Print the model name
    
print('Model Name: ', "SVM - Gaussian")

# actual values

actual = y_test

# predicted values

predicted = y_pred

# confusion matrix

matrix = confusion_matrix(actual,predicted, labels=[1,0],sample_weight=None, normalize=None)
print('Confusion matrix : \n', matrix)

# outcome values order in sklearn

tp, fn, fp, tn = confusion_matrix(actual,predicted,labels=[1,0]).reshape(-1)
print('Outcome values : \n', tp, fn, fp, tn)

# classification report for precision, recall f1-score and accuracy

C_Report = classification_report(actual,predicted,labels=[1,0])

print('Classification report : \n', C_Report)

# calculating the metrics

sensitivity = round(tp/(tp+fn), 3);
specificity = round(tn/(tn+fp), 3);
accuracy = round((tp+tn)/(tp+fp+tn+fn), 3);
balanced_accuracy = round((sensitivity+specificity)/2, 3);
precision = round(tp/(tp+fp), 3);
f1Score = round((2*tp/(2*tp + fp + fn)), 3);

# Matthews Correlation Coefficient (MCC). Range of values of MCC lie between -1 to +1. 
# A model with a score of +1 is a perfect model and -1 is a poor model

from math import sqrt

mx = (tp+fp) * (tp+fn) * (tn+fp) * (tn+fn)
MCC = round(((tp * tn) - (fp * fn)) / sqrt(mx), 3)

print('Accuracy :', round(accuracy*100, 2),'%')
print('Precision :', round(precision*100, 2),'%')
print('Recall :', round(sensitivity*100,2), '%')
print('F1 Score :', f1Score)
print('Specificity or True Negative Rate :', round(specificity*100,2), '%'  )
print('Balanced Accuracy :', round(balanced_accuracy*100, 2),'%')
print('MCC :', MCC)

# Area under ROC curve 

from sklearn.metrics import roc_curve, roc_auc_score

print('roc_auc_score:', round(roc_auc_score(y_test, y_pred), 3))

# ROC Curve

from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
logit_roc_auc = roc_auc_score(y_test, y_pred)
fpr, tpr, thresholds = roc_curve(y_test,ModelSVMGaussian.predict_proba(x_test)[:,1])
plt.figure()
# plt.plot
plt.plot(fpr, tpr, label= 'Classification Model' % logit_roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.savefig('Log_ROC')
plt.show()
# Out:
# Model Name:  SVM - Gaussian
# Confusion matrix :
#  [[  43   35]
#  [ 344 1073]]
# Outcome values :
#  43 35 344 1073
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.11      0.55      0.18        78
#            0       0.97      0.76      0.85      1417
#
#     accuracy                           0.75      1495
#    macro avg       0.54      0.65      0.52      1495
# weighted avg       0.92      0.75      0.82      1495
#
# Accuracy : 74.6 %
# Precision : 11.1 %
# Recall : 55.1 %
# F1 Score : 0.185
# Specificity or True Negative Rate : 75.7 %
# Balanced Accuracy : 65.4 %
# MCC : 0.157
# roc_auc_score: 0.654

# %% [markdown]
# # Sigmoid Kernel

# %%
# Training the SVM algorithm

from sklearn.svm import SVC

ModelSVMSig = SVC(kernel='sigmoid', random_state = 42, class_weight='balanced', probability=True)

# Train the model using balanced data 

ModelSVMSig.fit(x_train_resampled, y_train_resampled)

# Predict the model with test data set

y_pred = ModelSVMSig.predict(x_test)
y_pred_prob = ModelSVMSig.predict_proba(x_test)

# Print the model name
    
print('Model Name: ', "SVM - Sigmoid")

# Confusion matrix in sklearn

from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# actual values

actual = y_test

# predicted values

predicted = y_pred

# confusion matrix

matrix = confusion_matrix(actual,predicted, labels=[1,0],sample_weight=None, normalize=None)
print('Confusion matrix : \n', matrix)

# outcome values order in sklearn

tp, fn, fp, tn = confusion_matrix(actual,predicted,labels=[1,0]).reshape(-1)
print('Outcome values : \n', tp, fn, fp, tn)

# classification report for precision, recall f1-score and accuracy

C_Report = classification_report(actual,predicted,labels=[1,0])

print('Classification report : \n', C_Report)

# calculating the metrics

sensitivity = round(tp/(tp+fn), 3);
specificity = round(tn/(tn+fp), 3);
accuracy = round((tp+tn)/(tp+fp+tn+fn), 3);
balanced_accuracy = round((sensitivity+specificity)/2, 3);
precision = round(tp/(tp+fp), 3);
f1Score = round((2*tp/(2*tp + fp + fn)), 3);

# Matthews Correlation Coefficient (MCC). Range of values of MCC lie between -1 to +1. 
# A model with a score of +1 is a perfect model and -1 is a poor model

from math import sqrt

mx = (tp+fp) * (tp+fn) * (tn+fp) * (tn+fn)
MCC = round(((tp * tn) - (fp * fn)) / sqrt(mx), 3)

print('Accuracy :', round(accuracy*100, 2),'%')
print('Precision :', round(precision*100, 2),'%')
print('Recall :', round(sensitivity*100,2), '%')
print('F1 Score :', f1Score)
print('Specificity or True Negative Rate :', round(specificity*100,2), '%'  )
print('Balanced Accuracy :', round(balanced_accuracy*100, 2),'%')
print('MCC :', MCC)

# Area under ROC curve 

from sklearn.metrics import roc_curve, roc_auc_score

print('roc_auc_score:', round(roc_auc_score(y_test, y_pred), 3))

# ROC Curve

from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
logit_roc_auc = roc_auc_score(y_test, y_pred)
fpr, tpr, thresholds = roc_curve(y_test,ModelSVMSig.predict_proba(x_test)[:,1])
plt.figure()
# plt.plot
plt.plot(fpr, tpr, label= 'Classification Model' % logit_roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.savefig('Log_ROC')
plt.show()
# Out:
# Model Name:  SVM - Sigmoid
# Confusion matrix :
#  [[ 30  48]
#  [750 667]]
# Outcome values :
#  30 48 750 667
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.04      0.38      0.07        78
#            0       0.93      0.47      0.63      1417
#
#     accuracy                           0.47      1495
#    macro avg       0.49      0.43      0.35      1495
# weighted avg       0.89      0.47      0.60      1495
#
# Accuracy : 46.6 %
# Precision : 3.8 %
# Recall : 38.5 %
# F1 Score : 0.07
# Specificity or True Negative Rate : 47.1 %
# Balanced Accuracy : 42.8 %
# MCC : -0.064
# roc_auc_score: 0.428

# %% [markdown]
# # KNN Algorithm

# %%
# Bild KNN Model

from sklearn.neighbors import KNeighborsClassifier

from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

import sklearn.metrics as metrics

from sklearn.metrics import roc_curve, roc_auc_score

accuracy = []

for a in range(1, 21, 1):
    
    k = a
    
    # Build the model
    
    ModelKNN = KNeighborsClassifier(n_neighbors=k)
    
    # Train the model using balanced data
    ModelKNN.fit(x_train_resampled, y_train_resampled)
    
    # Predict the model
    
    y_pred = ModelKNN.predict(x_test)
    y_pred_prob = ModelKNN.predict_proba(x_test)
    
    print('KNN_K_value = ', a)
    
    # Print the model name
    
    print('Model Name: ', ModelKNN)
    
    # confusion matrix in sklearn
    
    from sklearn.metrics import confusion_matrix
    from sklearn.metrics import classification_report
    
    # actual values
    
    actual = y_test
    
    # predicted values
    
    predicted = y_pred
    
    # confusion matrix
    
    matrix = confusion_matrix(actual,predicted, labels=[1,0],sample_weight=None, normalize=None)
    print('Confusion matrix : \n', matrix)
    
    # outcome values order in sklearn
    
    tp, fn, fp, tn = confusion_matrix(actual,predicted,labels=[1,0]).reshape(-1)
    print('Outcome values : \n', tp, fn, fp, tn)
    
    # classification report for precision, recall f1-score and accuracy
    
    C_Report = classification_report(actual,predicted,labels=[1,0])
    
    print('Classification report : \n', C_Report)
    
    # calculating the metrics
    
    sensitivity = round(tp/(tp+fn), 3);
    specificity = round(tn/(tn+fp), 3);
    accuracy = round((tp+tn)/(tp+fp+tn+fn), 3);
    balanced_accuracy = round((sensitivity+specificity)/2, 3);
    
    precision = round(tp/(tp+fp), 3);
    f1Score = round((2*tp/(2*tp + fp + fn)), 3);
    
    # Matthews Correlation Coefficient (MCC). Range of values of MCC lie between -1 to +1. 
    # A model with a score of +1 is a perfect model and -1 is a poor model
    
    from math import sqrt
    
    mx = (tp+fp) * (tp+fn) * (tn+fp) * (tn+fn)
    MCC = round(((tp * tn) - (fp * fn)) / sqrt(mx), 3)
    
    print('Accuracy :', round(accuracy*100, 2),'%')
    print('Precision :', round(precision*100, 2),'%')
    print('Recall :', round(sensitivity*100,2), '%')
    print('F1 Score :', f1Score)
    print('Specificity or True Negative Rate :', round(specificity*100,2), '%'  )
    print('Balanced Accuracy :', round(balanced_accuracy*100, 2),'%')
    print('MCC :', MCC)
    
    # Area under ROC curve 
    
    from sklearn.metrics import roc_curve, roc_auc_score
    
    print('roc_auc_score:', round(roc_auc_score(actual, predicted), 3))
    
    # ROC Curve
    
    from sklearn.metrics import roc_auc_score
    from sklearn.metrics import roc_curve
    model_roc_auc = roc_auc_score(actual, predicted)
    fpr, tpr, thresholds = roc_curve(actual, ModelKNN.predict_proba(x_test)[:,1])
    plt.figure()
    # plt.plot(fpr, tpr, label='Logistic Regression (area = %0.2f)' % logit_roc_auc)
    plt.plot(fpr, tpr, label= 'Classification Model' % model_roc_auc)
    plt.plot([0, 1], [0, 1],'r--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver operating characteristic')
    plt.legend(loc="lower right")
    #plt.savefig('Log_ROC')
    plt.show()
    #------------------------------------------------------------------------------
# Out:
# KNN_K_value =  1
# Model Name:  KNeighborsClassifier(n_neighbors=1)
# Confusion matrix :
#  [[   8   70]
#  [  66 1351]]
# Outcome values :
#  8 70 66 1351
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.11      0.10      0.11        78
#            0       0.95      0.95      0.95      1417
#
#     accuracy                           0.91      1495
#    macro avg       0.53      0.53      0.53      1495
# weighted avg       0.91      0.91      0.91      1495
#
# Accuracy : 90.9 %
# Precision : 10.8 %
# Recall : 10.3 %
# F1 Score : 0.105
# Specificity or True Negative Rate : 95.3 %
# Balanced Accuracy : 52.8 %
# MCC : 0.057
# roc_auc_score: 0.528
# KNN_K_value =  2
# Model Name:  KNeighborsClassifier(n_neighbors=2)
# Confusion matrix :
#  [[   8   70]
#  [  66 1351]]
# Outcome values :
#  8 70 66 1351
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.11      0.10      0.11        78
#            0       0.95      0.95      0.95      1417
#
#     accuracy                           0.91      1495
#    macro avg       0.53      0.53      0.53      1495
# weighted avg       0.91      0.91      0.91      1495
#
# Accuracy : 90.9 %
# Precision : 10.8 %
# Recall : 10.3 %
# F1 Score : 0.105
# Specificity or True Negative Rate : 95.3 %
# Balanced Accuracy : 52.8 %
# MCC : 0.057
# roc_auc_score: 0.528
# KNN_K_value =  3
# Model Name:  KNeighborsClassifier(n_neighbors=3)
# Confusion matrix :
#  [[  12   66]
#  [ 122 1295]]
# Outcome values :
#  12 66 122 1295
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.09      0.15      0.11        78
#            0       0.95      0.91      0.93      1417
#
#     accuracy                           0.87      1495
#    macro avg       0.52      0.53      0.52      1495
# weighted avg       0.91      0.87      0.89      1495
#
# Accuracy : 87.4 %
# Precision : 9.0 %
# Recall : 15.4 %
# F1 Score : 0.113
# Specificity or True Negative Rate : 91.4 %
# Balanced Accuracy : 53.4 %
# MCC : 0.053
# roc_auc_score: 0.534
# KNN_K_value =  4
# Model Name:  KNeighborsClassifier(n_neighbors=4)
# Confusion matrix :
#  [[  12   66]
#  [ 122 1295]]
# Outcome values :
#  12 66 122 1295
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.09      0.15      0.11        78
#            0       0.95      0.91      0.93      1417
#
#     accuracy                           0.87      1495
#    macro avg       0.52      0.53      0.52      1495
# weighted avg       0.91      0.87      0.89      1495
#
# Accuracy : 87.4 %
# Precision : 9.0 %
# Recall : 15.4 %
# F1 Score : 0.113
# Specificity or True Negative Rate : 91.4 %
# Balanced Accuracy : 53.4 %
# MCC : 0.053
# roc_auc_score: 0.534
# KNN_K_value =  5
# Model Name:  KNeighborsClassifier()
# Confusion matrix :
#  [[  24   54]
#  [ 173 1244]]
# Outcome values :
#  24 54 173 1244
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.12      0.31      0.17        78
#            0       0.96      0.88      0.92      1417
#
#     accuracy                           0.85      1495
#    macro avg       0.54      0.59      0.55      1495
# weighted avg       0.91      0.85      0.88      1495
#
# Accuracy : 84.8 %
# Precision : 12.2 %
# Recall : 30.8 %
# F1 Score : 0.175
# Specificity or True Negative Rate : 87.8 %
# Balanced Accuracy : 59.3 %
# MCC : 0.122
# roc_auc_score: 0.593
# KNN_K_value =  6
# Model Name:  KNeighborsClassifier(n_neighbors=6)
# Confusion matrix :
#  [[  24   54]
#  [ 173 1244]]
# Outcome values :
#  24 54 173 1244
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.12      0.31      0.17        78
#            0       0.96      0.88      0.92      1417
#
#     accuracy                           0.85      1495
#    macro avg       0.54      0.59      0.55      1495
# weighted avg       0.91      0.85      0.88      1495
#
# Accuracy : 84.8 %
# Precision : 12.2 %
# Recall : 30.8 %
# F1 Score : 0.175
# Specificity or True Negative Rate : 87.8 %
# Balanced Accuracy : 59.3 %
# MCC : 0.122
# roc_auc_score: 0.593
# KNN_K_value =  7
# Model Name:  KNeighborsClassifier(n_neighbors=7)
# Confusion matrix :
#  [[  26   52]
#  [ 206 1211]]
# Outcome values :
#  26 52 206 1211
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.11      0.33      0.17        78
#            0       0.96      0.85      0.90      1417
#
#     accuracy                           0.83      1495
#    macro avg       0.54      0.59      0.54      1495
# weighted avg       0.91      0.83      0.87      1495
#
# Accuracy : 82.7 %
# Precision : 11.2 %
# Recall : 33.3 %
# F1 Score : 0.168
# Specificity or True Negative Rate : 85.5 %
# Balanced Accuracy : 59.4 %
# MCC : 0.115
# roc_auc_score: 0.594
# KNN_K_value =  8
# Model Name:  KNeighborsClassifier(n_neighbors=8)
# Confusion matrix :
#  [[  26   52]
#  [ 206 1211]]
# Outcome values :
#  26 52 206 1211
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.11      0.33      0.17        78
#            0       0.96      0.85      0.90      1417
#
#     accuracy                           0.83      1495
#    macro avg       0.54      0.59      0.54      1495
# weighted avg       0.91      0.83      0.87      1495
#
# Accuracy : 82.7 %
# Precision : 11.2 %
# Recall : 33.3 %
# F1 Score : 0.168
# Specificity or True Negative Rate : 85.5 %
# Balanced Accuracy : 59.4 %
# MCC : 0.115
# roc_auc_score: 0.594
# KNN_K_value =  9
# Model Name:  KNeighborsClassifier(n_neighbors=9)
# Confusion matrix :
#  [[  34   44]
#  [ 255 1162]]
# Outcome values :
#  34 44 255 1162
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.12      0.44      0.19        78
#            0       0.96      0.82      0.89      1417
#
#     accuracy                           0.80      1495
#    macro avg       0.54      0.63      0.54      1495
# weighted avg       0.92      0.80      0.85      1495
#
# Accuracy : 80.0 %
# Precision : 11.8 %
# Recall : 43.6 %
# F1 Score : 0.185
# Specificity or True Negative Rate : 82.0 %
# Balanced Accuracy : 62.8 %
# MCC : 0.144
# roc_auc_score: 0.628
# KNN_K_value =  10
# Model Name:  KNeighborsClassifier(n_neighbors=10)
# Confusion matrix :
#  [[  34   44]
#  [ 255 1162]]
# Outcome values :
#  34 44 255 1162
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.12      0.44      0.19        78
#            0       0.96      0.82      0.89      1417
#
#     accuracy                           0.80      1495
#    macro avg       0.54      0.63      0.54      1495
# weighted avg       0.92      0.80      0.85      1495
#
# Accuracy : 80.0 %
# Precision : 11.8 %
# Recall : 43.6 %
# F1 Score : 0.185
# Specificity or True Negative Rate : 82.0 %
# Balanced Accuracy : 62.8 %
# MCC : 0.144
# roc_auc_score: 0.628
# KNN_K_value =  11
# Model Name:  KNeighborsClassifier(n_neighbors=11)
# Confusion matrix :
#  [[  39   39]
#  [ 293 1124]]
# Outcome values :
#  39 39 293 1124
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.12      0.50      0.19        78
#            0       0.97      0.79      0.87      1417
#
#     accuracy                           0.78      1495
#    macro avg       0.54      0.65      0.53      1495
# weighted avg       0.92      0.78      0.84      1495
#
# Accuracy : 77.8 %
# Precision : 11.7 %
# Recall : 50.0 %
# F1 Score : 0.19
# Specificity or True Negative Rate : 79.3 %
# Balanced Accuracy : 64.7 %
# MCC : 0.157
# roc_auc_score: 0.647
# KNN_K_value =  12
# Model Name:  KNeighborsClassifier(n_neighbors=12)
# Confusion matrix :
#  [[  39   39]
#  [ 293 1124]]
# Outcome values :
#  39 39 293 1124
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.12      0.50      0.19        78
#            0       0.97      0.79      0.87      1417
#
#     accuracy                           0.78      1495
#    macro avg       0.54      0.65      0.53      1495
# weighted avg       0.92      0.78      0.84      1495
#
# Accuracy : 77.8 %
# Precision : 11.7 %
# Recall : 50.0 %
# F1 Score : 0.19
# Specificity or True Negative Rate : 79.3 %
# Balanced Accuracy : 64.7 %
# MCC : 0.157
# roc_auc_score: 0.647
# KNN_K_value =  13
# Model Name:  KNeighborsClassifier(n_neighbors=13)
# Confusion matrix :
#  [[  43   35]
#  [ 330 1087]]
# Outcome values :
#  43 35 330 1087
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.12      0.55      0.19        78
#            0       0.97      0.77      0.86      1417
#
#     accuracy                           0.76      1495
#    macro avg       0.54      0.66      0.52      1495
# weighted avg       0.92      0.76      0.82      1495
#
# Accuracy : 75.6 %
# Precision : 11.5 %
# Recall : 55.1 %
# F1 Score : 0.191
# Specificity or True Negative Rate : 76.7 %
# Balanced Accuracy : 65.9 %
# MCC : 0.164
# roc_auc_score: 0.659
# KNN_K_value =  14
# Model Name:  KNeighborsClassifier(n_neighbors=14)
# Confusion matrix :
#  [[  43   35]
#  [ 330 1087]]
# Outcome values :
#  43 35 330 1087
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.12      0.55      0.19        78
#            0       0.97      0.77      0.86      1417
#
#     accuracy                           0.76      1495
#    macro avg       0.54      0.66      0.52      1495
# weighted avg       0.92      0.76      0.82      1495
#
# Accuracy : 75.6 %
# Precision : 11.5 %
# Recall : 55.1 %
# F1 Score : 0.191
# Specificity or True Negative Rate : 76.7 %
# Balanced Accuracy : 65.9 %
# MCC : 0.164
# roc_auc_score: 0.659
# KNN_K_value =  15
# Model Name:  KNeighborsClassifier(n_neighbors=15)
# Confusion matrix :
#  [[  45   33]
#  [ 358 1059]]
# Outcome values :
#  45 33 358 1059
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.11      0.58      0.19        78
#            0       0.97      0.75      0.84      1417
#
#     accuracy                           0.74      1495
#    macro avg       0.54      0.66      0.52      1495
# weighted avg       0.93      0.74      0.81      1495
#
# Accuracy : 73.8 %
# Precision : 11.2 %
# Recall : 57.7 %
# F1 Score : 0.187
# Specificity or True Negative Rate : 74.7 %
# Balanced Accuracy : 66.2 %
# MCC : 0.163
# roc_auc_score: 0.662
# KNN_K_value =  16
# Model Name:  KNeighborsClassifier(n_neighbors=16)
# Confusion matrix :
#  [[  45   33]
#  [ 358 1059]]
# Outcome values :
#  45 33 358 1059
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.11      0.58      0.19        78
#            0       0.97      0.75      0.84      1417
#
#     accuracy                           0.74      1495
#    macro avg       0.54      0.66      0.52      1495
# weighted avg       0.93      0.74      0.81      1495
#
# Accuracy : 73.8 %
# Precision : 11.2 %
# Recall : 57.7 %
# F1 Score : 0.187
# Specificity or True Negative Rate : 74.7 %
# Balanced Accuracy : 66.2 %
# MCC : 0.163
# roc_auc_score: 0.662
# KNN_K_value =  17
# Model Name:  KNeighborsClassifier(n_neighbors=17)
# Confusion matrix :
#  [[  48   30]
#  [ 385 1032]]
# Outcome values :
#  48 30 385 1032
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.11      0.62      0.19        78
#            0       0.97      0.73      0.83      1417
#
#     accuracy                           0.72      1495
#    macro avg       0.54      0.67      0.51      1495
# weighted avg       0.93      0.72      0.80      1495
#
# Accuracy : 72.2 %
# Precision : 11.1 %
# Recall : 61.5 %
# F1 Score : 0.188
# Specificity or True Negative Rate : 72.8 %
# Balanced Accuracy : 67.2 %
# MCC : 0.168
# roc_auc_score: 0.672
# KNN_K_value =  18
# Model Name:  KNeighborsClassifier(n_neighbors=18)
# Confusion matrix :
#  [[  48   30]
#  [ 382 1035]]
# Outcome values :
#  48 30 382 1035
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.11      0.62      0.19        78
#            0       0.97      0.73      0.83      1417
#
#     accuracy                           0.72      1495
#    macro avg       0.54      0.67      0.51      1495
# weighted avg       0.93      0.72      0.80      1495
#
# Accuracy : 72.4 %
# Precision : 11.2 %
# Recall : 61.5 %
# F1 Score : 0.189
# Specificity or True Negative Rate : 73.0 %
# Balanced Accuracy : 67.2 %
# MCC : 0.17
# roc_auc_score: 0.673
# KNN_K_value =  19
# Model Name:  KNeighborsClassifier(n_neighbors=19)
# Confusion matrix :
#  [[ 51  27]
#  [420 997]]
# Outcome values :
#  51 27 420 997
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.11      0.65      0.19        78
#            0       0.97      0.70      0.82      1417
#
#     accuracy                           0.70      1495
#    macro avg       0.54      0.68      0.50      1495
# weighted avg       0.93      0.70      0.78      1495
#
# Accuracy : 70.1 %
# Precision : 10.8 %
# Recall : 65.4 %
# F1 Score : 0.186
# Specificity or True Negative Rate : 70.4 %
# Balanced Accuracy : 67.9 %
# MCC : 0.171
# roc_auc_score: 0.679
# KNN_K_value =  20
# Model Name:  KNeighborsClassifier(n_neighbors=20)
# Confusion matrix :
#  [[ 51  27]
#  [418 999]]
# Outcome values :
#  51 27 418 999
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.11      0.65      0.19        78
#            0       0.97      0.71      0.82      1417
#
#     accuracy                           0.70      1495
#    macro avg       0.54      0.68      0.50      1495
# weighted avg       0.93      0.70      0.78      1495
#
# Accuracy : 70.2 %
# Precision : 10.9 %
# Recall : 65.4 %
# F1 Score : 0.186
# Specificity or True Negative Rate : 70.5 %
# Balanced Accuracy : 68.0 %
# MCC : 0.172
# roc_auc_score: 0.679

# %% [markdown]
# # Compare the classification Algorithms

# %%
# Load the results file for classification
EMResults = pd.read_csv(r"C:\Users\Praveen\Desktop\INTERNSHIP 26-07\PROJECT\EMResults.csv",header=0)
EMResults.head()
# Out:
# Empty DataFrame
# Columns: [Model Name, True_Positive, False_Negative, False_Positive, True_Negative, Accuracy, Precision, Recall, F1 Score, Specificity, MCC, ROC_AUC_Score, Balanced Accuracy]
# Index: []

# %%
# Build the Calssification models and compare the results

from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB

# Create objects of classification algorithm with default hyper-parameters

ModelLR = LogisticRegression()
ModelDC = DecisionTreeClassifier()
ModelRF = RandomForestClassifier()
ModelET = ExtraTreesClassifier()
ModelKNN = KNeighborsClassifier(n_neighbors=5)
ModelSVM = SVC(kernel='rbf', random_state = 42, class_weight='balanced', probability=True)
ModelGNB = GaussianNB()

# Evalution matrix for all the algorithms

MM = [ModelLR, ModelDC, ModelRF, ModelET, ModelKNN, ModelSVM, ModelGNB]
for models in MM:
    
    # Fit the model
    
    models.fit(x_train_resampled, y_train_resampled)
    
    # Prediction
    
    y_pred = models.predict(x_test)
    y_pred_prob = models.predict_proba(x_test)
    
    # Print the model name
    
    print('Model Name: ', models)
    
    # confusion matrix in sklearn

    from sklearn.metrics import confusion_matrix
    from sklearn.metrics import classification_report

    # actual values

    actual = y_test

    # predicted values

    predicted = y_pred

    # confusion matrix

    matrix = confusion_matrix(actual,predicted, labels=[1,0],sample_weight=None, normalize=None)
    print('Confusion matrix : \n', matrix)

    # outcome values order in sklearn

    tp, fn, fp, tn = confusion_matrix(actual,predicted,labels=[1,0]).reshape(-1)
    print('Outcome values : \n', tp, fn, fp, tn)

    # classification report for precision, recall f1-score and accuracy

    C_Report = classification_report(actual,predicted,labels=[1,0])

    print('Classification report : \n', C_Report)

    # calculating the metrics

    sensitivity = round(tp/(tp+fn), 3);
    specificity = round(tn/(tn+fp), 3);
    accuracy = round((tp+tn)/(tp+fp+tn+fn), 3);
    balanced_accuracy = round((sensitivity+specificity)/2, 3);
    
    precision = round(tp/(tp+fp), 3);
    f1Score = round((2*tp/(2*tp + fp + fn)), 3);

    # Matthews Correlation Coefficient (MCC). Range of values of MCC lie between -1 to +1. 
    # A model with a score of +1 is a perfect model and -1 is a poor model

    from math import sqrt

    mx = (tp+fp) * (tp+fn) * (tn+fp) * (tn+fn)
    MCC = round(((tp * tn) - (fp * fn)) / sqrt(mx), 3)

    print('Accuracy :', round(accuracy*100, 2),'%')
    print('Precision :', round(precision*100, 2),'%')
    print('Recall :', round(sensitivity*100,2), '%')
    print('F1 Score :', f1Score)
    print('Specificity or True Negative Rate :', round(specificity*100,2), '%'  )
    print('Balanced Accuracy :', round(balanced_accuracy*100, 2),'%')
    print('MCC :', MCC)

    # Area under ROC curve 

    from sklearn.metrics import roc_curve, roc_auc_score

    print('roc_auc_score:', round(roc_auc_score(actual, predicted), 3))
    
    # ROC Curve
    
    from sklearn.metrics import roc_auc_score
    from sklearn.metrics import roc_curve
    logit_roc_auc = roc_auc_score(actual, predicted)
    fpr, tpr, thresholds = roc_curve(actual, models.predict_proba(x_test)[:,1])
    plt.figure()
    # plt.plot(fpr, tpr, label='Logistic Regression (area = %0.2f)' % logit_roc_auc)
    plt.plot(fpr, tpr, label= 'Classification Model' % logit_roc_auc)
    plt.plot([0, 1], [0, 1],'r--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver operating characteristic')
    plt.legend(loc="lower right")
    plt.savefig('Log_ROC')
    plt.show()
    print('-----------------------------------------------------------------------------------------------------')
    #----------------------------------------------------------------------------------------------------------
    
    new_row = {'Model Name' : models,
               'True_Positive' : tp, 
               'False_Negative' : fn, 
               'False_Positive' : fp,
               'True_Negative' : tn,
               'Accuracy' : accuracy,
               'Precision' : precision,
               'Recall' : sensitivity,
               'F1 Score' : f1Score,
               'Specificity' : specificity,
               'MCC':MCC,
               'ROC_AUC_Score':roc_auc_score(actual, predicted),
               'Balanced Accuracy':balanced_accuracy}
    EMResults =EMResults.append(new_row, ignore_index=True)
    #----------------------------------------------------------------------------------------------------------
# Out:
# Model Name:  LogisticRegression()
# Confusion matrix :
#  [[  60   18]
#  [ 359 1058]]
# Outcome values :
#  60 18 359 1058
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.14      0.77      0.24        78
#            0       0.98      0.75      0.85      1417
#
#     accuracy                           0.75      1495
#    macro avg       0.56      0.76      0.55      1495
# weighted avg       0.94      0.75      0.82      1495
#
# Accuracy : 74.8 %
# Precision : 14.3 %
# Recall : 76.9 %
# F1 Score : 0.241
# Specificity or True Negative Rate : 74.7 %
# Balanced Accuracy : 75.8 %
# MCC : 0.255
# roc_auc_score: 0.758
# -----------------------------------------------------------------------------------------------------
# Model Name:  DecisionTreeClassifier()
# Confusion matrix :
#  [[   7   71]
#  [  49 1368]]
# Outcome values :
#  7 71 49 1368
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.12      0.09      0.10        78
#            0       0.95      0.97      0.96      1417
#
#     accuracy                           0.92      1495
#    macro avg       0.54      0.53      0.53      1495
# weighted avg       0.91      0.92      0.91      1495
#
# Accuracy : 92.0 %
# Precision : 12.5 %
# Recall : 9.0 %
# F1 Score : 0.104
# Specificity or True Negative Rate : 96.5 %
# Balanced Accuracy : 52.8 %
# MCC : 0.065
# roc_auc_score: 0.528
# -----------------------------------------------------------------------------------------------------
# Model Name:  RandomForestClassifier()
# Confusion matrix :
#  [[   2   76]
#  [  10 1407]]
# Outcome values :
#  2 76 10 1407
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.17      0.03      0.04        78
#            0       0.95      0.99      0.97      1417
#
#     accuracy                           0.94      1495
#    macro avg       0.56      0.51      0.51      1495
# weighted avg       0.91      0.94      0.92      1495
#
# Accuracy : 94.2 %
# Precision : 16.7 %
# Recall : 2.6 %
# F1 Score : 0.044
# Specificity or True Negative Rate : 99.3 %
# Balanced Accuracy : 50.9 %
# MCC : 0.046
# roc_auc_score: 0.509
# -----------------------------------------------------------------------------------------------------
# Model Name:  ExtraTreesClassifier()
# Confusion matrix :
#  [[   2   76]
#  [  12 1405]]
# Outcome values :
#  2 76 12 1405
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.14      0.03      0.04        78
#            0       0.95      0.99      0.97      1417
#
#     accuracy                           0.94      1495
#    macro avg       0.55      0.51      0.51      1495
# weighted avg       0.91      0.94      0.92      1495
#
# Accuracy : 94.1 %
# Precision : 14.3 %
# Recall : 2.6 %
# F1 Score : 0.043
# Specificity or True Negative Rate : 99.2 %
# Balanced Accuracy : 50.9 %
# MCC : 0.04
# roc_auc_score: 0.509
# -----------------------------------------------------------------------------------------------------
# Model Name:  KNeighborsClassifier()
# Confusion matrix :
#  [[  24   54]
#  [ 173 1244]]
# Outcome values :
#  24 54 173 1244
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.12      0.31      0.17        78
#            0       0.96      0.88      0.92      1417
#
#     accuracy                           0.85      1495
#    macro avg       0.54      0.59      0.55      1495
# weighted avg       0.91      0.85      0.88      1495
#
# Accuracy : 84.8 %
# Precision : 12.2 %
# Recall : 30.8 %
# F1 Score : 0.175
# Specificity or True Negative Rate : 87.8 %
# Balanced Accuracy : 59.3 %
# MCC : 0.122
# roc_auc_score: 0.593
# -----------------------------------------------------------------------------------------------------
# Model Name:  SVC(class_weight='balanced', probability=True, random_state=42)
# Confusion matrix :
#  [[  43   35]
#  [ 344 1073]]
# Outcome values :
#  43 35 344 1073
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.11      0.55      0.18        78
#            0       0.97      0.76      0.85      1417
#
#     accuracy                           0.75      1495
#    macro avg       0.54      0.65      0.52      1495
# weighted avg       0.92      0.75      0.82      1495
#
# Accuracy : 74.6 %
# Precision : 11.1 %
# Recall : 55.1 %
# F1 Score : 0.185
# Specificity or True Negative Rate : 75.7 %
# Balanced Accuracy : 65.4 %
# MCC : 0.157
# roc_auc_score: 0.654
# -----------------------------------------------------------------------------------------------------
# Model Name:  GaussianNB()
# Confusion matrix :
#  [[ 64  14]
#  [421 996]]
# Outcome values :
#  64 14 421 996
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.13      0.82      0.23        78
#            0       0.99      0.70      0.82      1417
#
#     accuracy                           0.71      1495
#    macro avg       0.56      0.76      0.52      1495
# weighted avg       0.94      0.71      0.79      1495
#
# Accuracy : 70.9 %
# Precision : 13.2 %
# Recall : 82.1 %
# F1 Score : 0.227
# Specificity or True Negative Rate : 70.3 %
# Balanced Accuracy : 76.2 %
# MCC : 0.249
# roc_auc_score: 0.762
# -----------------------------------------------------------------------------------------------------

# %%
EMResults.head(10)
# Out:
#                                           Model Name True_Positive  \
# 0                               LogisticRegression()            60
# 1                           DecisionTreeClassifier()             7
# 2  (DecisionTreeClassifier(max_features='sqrt', r...             2
# 3  (ExtraTreeClassifier(random_state=1537775924),...             2
# 4                             KNeighborsClassifier()            24
# 5  SVC(class_weight='balanced', probability=True,...            43
# 6                                       GaussianNB()            64
#
#   False_Negative False_Positive True_Negative  Accuracy  Precision  Recall  \
# 0             18            359          1058     0.748      0.143   0.769
# 1             71             49          1368     0.920      0.125   0.090
# 2             76             10          1407     0.942      0.167   0.026
# 3             76             12          1405     0.941      0.143   0.026
# 4             54            173          1244     0.848      0.122   0.308
# 5             35            344          1073     0.746      0.111   0.551
# 6             14            421           996     0.709      0.132   0.821
#
#    F1 Score  Specificity    MCC  ROC_AUC_Score  Balanced Accuracy
# 0     0.241        0.747  0.255       0.757939              0.758
# 1     0.104        0.965  0.065       0.527582              0.528
# 2     0.044        0.993  0.046       0.509292              0.509
# 3     0.043        0.992  0.040       0.508586              0.509
# 4     0.175        0.878  0.122       0.592802              0.593
# 5     0.185        0.757  0.157       0.654258              0.654
# 6     0.227        0.703  0.249       0.761703              0.762

# %%
# Assuming you have also predicted using DecisionTreeClassifier (ModelDC)
y_predDC=ModelDC.predict(x_test)

# %%
# Display the Final results

Results = pd.DataFrame({ 'stroke_A':y_test, 'stroke_P':y_pred})

# Merge two Dataframes on index of both the dataframes

ResultsFinal = pd.DataFrame({'stroke_A': y_test, 'stroke_P': y_pred})

#Display 10 records randomly 
ResultsFinal.sample(10)
# Out:
#       stroke_A  stroke_P
# 4063         0         0
# 3634         0         1
# 4902         0         1
# 4958         0         0
# 2220         0         0
# 1417         0         0
# 4204         0         0
# 198          1         1
# 2101         0         1
# 4561         0         0
