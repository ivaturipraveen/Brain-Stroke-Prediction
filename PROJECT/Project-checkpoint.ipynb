# %%
#Step -1
#importing the libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import pandasql as ps

# Set to display all the columns of the dataset
pd.set_option("display.max_columns",None)

#Ignore harmless warnings
import warnings
warnings.filterwarnings("ignore")

# %%
#Step -2
#Load the data
bsdata=pd.read_csv(r"C:\Users\Dlc\Desktop\INTERNSHIP 26-07\PROJECT\full_data.csv",header=0)
#Step -3
#Copy to back_up file
bsdata_bk=bsdata.copy()
#Display first 5 records
bsdata.head()
# Out:
#    gender   age  hypertension  heart_disease ever_married      work_type  \
# 0    Male  67.0             0              1          Yes        Private
# 1    Male  80.0             0              1          Yes        Private
# 2  Female  49.0             0              0          Yes        Private
# 3  Female  79.0             1              0          Yes  Self-employed
# 4    Male  81.0             0              0          Yes        Private
#
#   Residence_type  avg_glucose_level   bmi   smoking_status  stroke
# 0          Urban             228.69  36.6  formerly smoked       1
# 1          Rural             105.92  32.5     never smoked       1
# 2          Urban             171.23  34.4           smokes       1
# 3          Rural             174.12  24.0     never smoked       1
# 4          Urban             186.21  29.0  formerly smoked       1

# %%
#Step -4
#Display the data set information
bsdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4981 entries, 0 to 4980
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   gender             4981 non-null   object
#  1   age                4981 non-null   float64
#  2   hypertension       4981 non-null   int64
#  3   heart_disease      4981 non-null   int64
#  4   ever_married       4981 non-null   object
#  5   work_type          4981 non-null   object
#  6   Residence_type     4981 non-null   object
#  7   avg_glucose_level  4981 non-null   float64
#  8   bmi                4981 non-null   float64
#  9   smoking_status     4981 non-null   object
#  10  stroke             4981 non-null   int64
# dtypes: float64(3), int64(3), object(5)
# memory usage: 428.2+ KB

# %%
bsdata.stroke.value_counts()
# Out:
# 0    4733
# 1     248
# Name: stroke, dtype: int64

# %%
# Count the target or dependent variable by '0' & '1' and their proportion 
# (>= 10 : 1, then the dataset is imbalance data)

stroke_count = bsdata.stroke.value_counts()
print("proportion: ",stroke_count[0]/stroke_count[1],":1")
# Out:
# proportion:  19.08467741935484 :1

# %%
#Step -5
#Display the unique values of the data set
bsdata.nunique()
# Out:
# gender                  2
# age                   104
# hypertension            2
# heart_disease           2
# ever_married            2
# work_type               4
# Residence_type          2
# avg_glucose_level    3895
# bmi                   342
# smoking_status          4
# stroke                  2
# dtype: int64

# %%
# Count the missig values by each variable, if available
bsdata.isnull().sum()
# Out:
# gender               0
# age                  0
# hypertension         0
# heart_disease        0
# ever_married         0
# work_type            0
# Residence_type       0
# avg_glucose_level    0
# bmi                  0
# smoking_status       0
# stroke               0
# dtype: int64

# %%
#Step -6
#Check the duplicate  values with in  dataset if available
bsdata_dup=bsdata[bsdata.duplicated(keep='last')]
bsdata_dup
# Out:
# Empty DataFrame
# Columns: [gender, age, hypertension, heart_disease, ever_married, work_type, Residence_type, avg_glucose_level, bmi, smoking_status, stroke]
# Index: []

# %%
#Step 7
# plotting histogram for the target variable.

#sns.histplot(bsdata['stroke'],kde=True)

# %%
'''
Based on analysis:-

1) ## Females are more likely to get a stroke than male.
2) ### People who are employed in the private sector are more likely to get a stroke.
3) There is no clear relation between heart diseases and hypertension with stroke.
4) Smoking is not a conclusive evidence to determine stroke.
5) ### People who are obese,overweight are more likely to get a stroke.
6) ## People with low glucose level are likely to get a stroke.
7) ## Senior and super senior citizens are more likely to get a stroke.
8) Marriage doesn't determine stroke.

'''
# Out:
# "\nBased on analysis:-\n\n1) ## Females are more likely to get a stroke than male.\n2) ### People who are employed in the private sector are more likely to get a stroke.\n3) There is no clear relation between heart diseases and hypertension with stroke.\n4) Smoking is not a conclusive evidence to determine stroke.\n5) ### People who are obese,overweight are more likely to get a stroke.\n6) ## People with low glucose level are likely to get a stroke.\n7) ## Senior and super senior citizens are more likely to get a stroke.\n8) Marriage doesn't determine stroke.\n\n"

# %%
#Display the unique values by count for 'gender'
bsdata['gender'].value_counts()
# Out:
# Female    2907
# Male      2074
# Name: gender, dtype: int64

# %%
#Display the unique values by count for 'work_type'
bsdata['work_type'].value_counts()
# Out:
# Private          2860
# Self-employed     804
# children          673
# Govt_job          644
# Name: work_type, dtype: int64

# %%
#Display the unique values by count for 'ever_married'
bsdata['ever_married'].value_counts()
# Out:
# Yes    3280
# No     1701
# Name: ever_married, dtype: int64

# %%
#Display the unique values by count for 'Residence_type'
bsdata['Residence_type'].value_counts()
# Out:
# Urban    2532
# Rural    2449
# Name: Residence_type, dtype: int64

# %%
#Display the unique values by count for 'smoking_status'
bsdata['smoking_status'].value_counts()
# Out:
# never smoked       1838
# Unknown            1500
# formerly smoked     867
# smokes              776
# Name: smoking_status, dtype: int64

# %%
#Step -8,9
#use LabelEncoder for target variable
object_col = ["gender", "ever_married", "Residence_type","smoking_status","work_type"]
from sklearn.preprocessing import LabelEncoder
LE = LabelEncoder()
for col in object_col:
    bsdata[col] = LE.fit_transform(bsdata[col])

# %%
bsdata['gender'].value_counts()
# Out:
# 0    2907
# 1    2074
# Name: gender, dtype: int64

# %%
bsdata['ever_married'].value_counts()
# Out:
# 1    3280
# 0    1701
# Name: ever_married, dtype: int64

# %%
bsdata['Residence_type'].value_counts()
# Out:
# 1    2532
# 0    2449
# Name: Residence_type, dtype: int64

# %%
bsdata['smoking_status'].value_counts()
# Out:
# 2    1838
# 0    1500
# 1     867
# 3     776
# Name: smoking_status, dtype: int64

# %%
bsdata['work_type'].value_counts()
# Out:
# 1    2860
# 2     804
# 3     673
# 0     644
# Name: work_type, dtype: int64

# %%
#Display the data set information
bsdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4981 entries, 0 to 4980
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   gender             4981 non-null   int32
#  1   age                4981 non-null   float64
#  2   hypertension       4981 non-null   int64
#  3   heart_disease      4981 non-null   int64
#  4   ever_married       4981 non-null   int32
#  5   work_type          4981 non-null   int32
#  6   Residence_type     4981 non-null   int32
#  7   avg_glucose_level  4981 non-null   float64
#  8   bmi                4981 non-null   float64
#  9   smoking_status     4981 non-null   int32
#  10  stroke             4981 non-null   int64
# dtypes: float64(3), int32(5), int64(3)
# memory usage: 330.9 KB

# %%
bsdata.head()
# Out:
#    gender   age  hypertension  heart_disease  ever_married  work_type  \
# 0       1  67.0             0              1             1          1
# 1       1  80.0             0              1             1          1
# 2       0  49.0             0              0             1          1
# 3       0  79.0             1              0             1          2
# 4       1  81.0             0              0             1          1
#
#    Residence_type  avg_glucose_level   bmi  smoking_status  stroke
# 0               1             228.69  36.6               1       1
# 1               0             105.92  32.5               2       1
# 2               1             171.23  34.4               3       1
# 3               0             174.12  24.0               2       1
# 4               1             186.21  29.0               1       1

# %%
# Display descriptive statistics
bsdata.describe()
# Out:
#             gender          age  hypertension  heart_disease  ever_married  \
# count  4981.000000  4981.000000   4981.000000    4981.000000   4981.000000
# mean      0.416382    43.419859      0.096165       0.055210      0.658502
# std       0.493008    22.662755      0.294848       0.228412      0.474260
# min       0.000000     0.080000      0.000000       0.000000      0.000000
# 25%       0.000000    25.000000      0.000000       0.000000      0.000000
# 50%       0.000000    45.000000      0.000000       0.000000      1.000000
# 75%       1.000000    61.000000      0.000000       0.000000      1.000000
# max       1.000000    82.000000      1.000000       1.000000      1.000000
#
#          work_type  Residence_type  avg_glucose_level          bmi  \
# count  4981.000000     4981.000000        4981.000000  4981.000000
# mean      1.302349        0.508332         105.943562    28.498173
# std       0.860170        0.499981          45.075373     6.790464
# min       0.000000        0.000000          55.120000    14.000000
# 25%       1.000000        0.000000          77.230000    23.700000
# 50%       1.000000        1.000000          91.850000    28.100000
# 75%       2.000000        1.000000         113.860000    32.600000
# max       3.000000        1.000000         271.740000    48.900000
#
#        smoking_status       stroke
# count     4981.000000  4981.000000
# mean         1.379442     0.049789
# std          1.072180     0.217531
# min          0.000000     0.000000
# 25%          0.000000     0.000000
# 50%          2.000000     0.000000
# 75%          2.000000     0.000000
# max          3.000000     1.000000

# %%
bsdata.corrwith(bsdata['stroke'])
# Out:
# gender               0.008870
# age                  0.246478
# hypertension         0.131965
# heart_disease        0.134610
# ever_married         0.108398
# work_type           -0.041835
# Residence_type       0.016494
# avg_glucose_level    0.133227
# bmi                  0.056926
# smoking_status       0.027463
# stroke               1.000000
# dtype: float64

# %%
#have very low correlation with the target variable so dropping them

# %%
#dropping the columns
#badata = bsdata.drop(['gender','work_type','Residence_type','bmi','smoking_status'],axis=1)

# %%
#Identify the variables to normalize with minmaxscalar
cols=['age','gender','hypertension','ever_married','heart_disease','work_type','Residence_type','avg_glucose_level','bmi','smoking_status']

# %%
#Step -10
# identify the Independent and Target (dependent variables)
IndepVar = []
for col in bsdata.columns:
    if col != 'stroke':
        IndepVar.append(col)
TargetVar = 'stroke'
x = bsdata[IndepVar]
y = bsdata[TargetVar]

# %%
# Random oversampling can be implemented using the RandomOverSampler class

from imblearn.over_sampling import RandomOverSampler

oversample = RandomOverSampler(sampling_strategy=0.125)

x_over, y_over = oversample.fit_resample(x, y)

print(x_over.shape)

print(y_over.shape)
# Out:
# (5324, 10)
# (5324,)

# %%
#Step -11
# Splitting the dataset into train and test 

from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x_over, y_over, test_size = 0.30, random_state = 42)

# Display the shape 

x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((3726, 10), (1598, 10), (3726,), (1598,))

# %%
#Step -12
# Scaling the features by using MinMaxScaler

from sklearn.preprocessing import MinMaxScaler

mmscaler = MinMaxScaler(feature_range=(0, 1))

x_train[cols] = mmscaler.fit_transform(x_train[cols])
x_train = pd.DataFrame(x_train)

x_test[cols] = mmscaler.fit_transform(x_test[cols])
x_test = pd.DataFrame(x_test)

# %%
stroke_count = y_train.value_counts()
print("proportion: ",stroke_count[0]/stroke_count[1],":1")
# Out:
# proportion:  8.315 :1

# %%
#Load the result file for SVM
SVMResults=pd.read_csv(r"C:\Users\Dlc\Desktop\INTERNSHIP 26-07\PROJECT\EMResults.csv",header=0)
#Display the  first five records
SVMResults.head()
# Out:
# Empty DataFrame
# Columns: [Model Name, True_Positive, False_Negative, False_Positive, True_Negative, Accuracy, Precision, Recall, F1 Score, Specificity, MCC, ROC_AUC_Score, Balanced Accuracy]
# Index: []

# %% [markdown]
# # SVM- Linear Kernel

# %%
# Training the SVM algorithm with train dataset

from sklearn.svm import SVC

ModelSVM1 = SVC(C=1.0, kernel='linear', degree=3, gamma='scale', coef0=0.0, shrinking=True, 
                probability=True, tol=0.001, cache_size=200, class_weight=None, verbose=False, 
                max_iter=- 1, decision_function_shape='ovr', break_ties=False, random_state=None)

# Train the model with train data 

ModelSVM1 = ModelSVM1.fit(x_train, y_train)

# Predict the model with test data set

y_pred = ModelSVM1.predict(x_test)
y_pred_prob = ModelSVM1.predict_proba(x_test)

# Print the model name
    
print('Model Name: ', "SVM - Linear")

# Confusion matrix in sklearn

from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# actual values

actual = y_test

# predicted values

predicted = y_pred

# confusion matrix

matrix = confusion_matrix(actual,predicted, labels=[1,0],sample_weight=None, normalize=None)
print('Confusion matrix : \n', matrix)

# outcome values order in sklearn

tp, fn, fp, tn = confusion_matrix(actual,predicted,labels=[1,0]).reshape(-1)
print('Outcome values : \n', tp, fn, fp, tn)

# classification report for precision, recall f1-score and accuracy

C_Report = classification_report(actual,predicted,labels=[1,0])

print('Classification report : \n', C_Report)

# calculating the metrics

sensitivity = round(tp/(tp+fn), 3);
specificity = round(tn/(tn+fp), 3);
accuracy = round((tp+tn)/(tp+fp+tn+fn), 3);
balanced_accuracy = round((sensitivity+specificity)/2, 3);
precision = round(tp/(tp+fp), 3);
f1Score = round((2*tp/(2*tp + fp + fn)), 3);

# Matthews Correlation Coefficient (MCC). Range of values of MCC lie between -1 to +1. 
# A model with a score of +1 is a perfect model and -1 is a poor model

from math import sqrt

mx = (tp+fp) * (tp+fn) * (tn+fp) * (tn+fn)
MCC = round(((tp * tn) - (fp * fn)) / sqrt(mx), 3)

print('Accuracy :', round(accuracy*100, 2),'%')
print('Precision :', round(precision*100, 2),'%')
print('Recall :', round(sensitivity*100,2), '%')
print('F1 Score :', f1Score)
print('Specificity or True Negative Rate :', round(specificity*100,2), '%'  )
print('Balanced Accuracy :', round(balanced_accuracy*100, 2),'%')
print('MCC :', MCC)

# Area under ROC curve 

from sklearn.metrics import roc_curve, roc_auc_score

print('roc_auc_score:', round(roc_auc_score(actual, predicted), 3))

# ROC Curve

from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
model_roc_auc = roc_auc_score(actual, predicted)
fpr, tpr, thresholds = roc_curve(actual,ModelSVM1.predict_proba(x_test)[:,1])
plt.figure()
# plt.plot(fpr, tpr, label='Logistic Regression (area = %0.2f)' % logit_roc_auc)
plt.plot(fpr, tpr, label= 'Classification Model' % model_roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.savefig('Log_ROC')
plt.show() 
new_row = {'Model Name' : "SVM - Linear",
            'True_Positive' : tp, 
            'False_Negative' : fn, 
            'False_Positive' : fp,
            'True_Negative' : tn,
            'Accuracy' : accuracy,
            'Precision' : precision,
            'Recall' : sensitivity,
            'F1 Score' : f1Score,
            'Specificity' : specificity,
            'MCC':MCC,
            'ROC_AUC_Score':roc_auc_score(actual, predicted),
            'Balanced Accuracy':balanced_accuracy}
SVMResults = SVMResults.append(new_row, ignore_index=True)
#-----------------------------------------------------------------------------------------------------------
# Out:
# Model Name:  SVM - Linear
# Confusion matrix :
#  [[   0  191]
#  [   0 1407]]
# Outcome values :
#  0 191 0 1407
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.00      0.00      0.00       191
#            0       0.88      1.00      0.94      1407
#
#     accuracy                           0.88      1598
#    macro avg       0.44      0.50      0.47      1598
# weighted avg       0.78      0.88      0.82      1598
#
# Accuracy : 88.0 %
# Precision : nan %
# Recall : 0.0 %
# F1 Score : 0.0
# Specificity or True Negative Rate : 100.0 %
# Balanced Accuracy : 50.0 %
# MCC : nan
# roc_auc_score: 0.5

# %% [markdown]
# # Polynomial Kernel

# %%
# Training the SVM algorithm

from sklearn.svm import SVC

ModelSVMPoly = SVC(kernel='poly', degree=2, probability=True)

# Train the model

ModelSVMPoly.fit(x_train, y_train)

# Predict the model with test data set

y_pred = ModelSVMPoly.predict(x_test)
y_pred_prob = ModelSVMPoly.predict_proba(x_test)

# Print the model name
    
print('Model Name: ', "SVM - Polynominal")

# Confusion matrix in sklearn

from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# actual values

actual = y_test

# predicted values

predicted = y_pred

# confusion matrix

matrix = confusion_matrix(actual,predicted, labels=[1,0],sample_weight=None, normalize=None)
print('Confusion matrix : \n', matrix)

# outcome values order in sklearn

tp, fn, fp, tn = confusion_matrix(actual,predicted,labels=[1,0]).reshape(-1)
print('Outcome values : \n', tp, fn, fp, tn)

# classification report for precision, recall f1-score and accuracy

C_Report = classification_report(actual,predicted,labels=[1,0])

print('Classification report : \n', C_Report)

# calculating the metrics

sensitivity = round(tp/(tp+fn), 3);
specificity = round(tn/(tn+fp), 3);
accuracy = round((tp+tn)/(tp+fp+tn+fn), 3);
balanced_accuracy = round((sensitivity+specificity)/2, 3);
precision = round(tp/(tp+fp), 3);
f1Score = round((2*tp/(2*tp + fp + fn)), 3);

# Matthews Correlation Coefficient (MCC). Range of values of MCC lie between -1 to +1. 
# A model with a score of +1 is a perfect model and -1 is a poor model

from math import sqrt

mx = (tp+fp) * (tp+fn) * (tn+fp) * (tn+fn)
MCC = round(((tp * tn) - (fp * fn)) / sqrt(mx), 3)

print('Accuracy :', round(accuracy*100, 2),'%')
print('Precision :', round(precision*100, 2),'%')
print('Recall :', round(sensitivity*100,2), '%')
print('F1 Score :', f1Score)
print('Specificity or True Negative Rate :', round(specificity*100,2), '%'  )
print('Balanced Accuracy :', round(balanced_accuracy*100, 2),'%')
print('MCC :', MCC)

# Area under ROC curve 

from sklearn.metrics import roc_curve, roc_auc_score

print('roc_auc_score:', round(roc_auc_score(y_test, y_pred), 3))

# ROC Curve

from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
logit_roc_auc = roc_auc_score(y_test, y_pred)
fpr, tpr, thresholds = roc_curve(y_test,ModelSVMPoly.predict_proba(x_test)[:,1])
plt.figure()
# plt.plot
plt.plot(fpr, tpr, label= 'Classification Model' % logit_roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.savefig('Log_ROC')
plt.show() 
new_row = {'Model Name' : "SVM - Polynomial",
            'True_Positive' : tp, 
            'False_Negative' : fn, 
            'False_Positive' : fp,
            'True_Negative' : tn,
            'Accuracy' : accuracy,
            'Precision' : precision,
            'Recall' : sensitivity,
            'F1 Score' : f1Score,
            'Specificity' : specificity,
            'MCC':MCC,
            'ROC_AUC_Score':roc_auc_score(actual, predicted),
            'Balanced Accuracy':balanced_accuracy}
SVMResults = SVMResults.append(new_row, ignore_index=True)
#-----------------------------------------------------------------------------------------------------------
# Out:
# Model Name:  SVM - Polynominal
# Confusion matrix :
#  [[   0  191]
#  [   0 1407]]
# Outcome values :
#  0 191 0 1407
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.00      0.00      0.00       191
#            0       0.88      1.00      0.94      1407
#
#     accuracy                           0.88      1598
#    macro avg       0.44      0.50      0.47      1598
# weighted avg       0.78      0.88      0.82      1598
#
# Accuracy : 88.0 %
# Precision : nan %
# Recall : 0.0 %
# F1 Score : 0.0
# Specificity or True Negative Rate : 100.0 %
# Balanced Accuracy : 50.0 %
# MCC : nan
# roc_auc_score: 0.5

# %% [markdown]
# # Gaussian Kernel

# %%
# Training the SVM algorithm

from sklearn.svm import SVC

ModelSVMGaussian = SVC(kernel='rbf', random_state = 42, class_weight='balanced', probability=True)

# Train the model

ModelSVMGaussian.fit(x_train, y_train)

# Predict the model with test data set

y_pred = ModelSVMGaussian.predict(x_test)
y_pred_prob = ModelSVMGaussian.predict_proba(x_test)

# Confusion matrix in sklearn

from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# Print the model name
    
print('Model Name: ', "SVM - Gaussian")

# actual values

actual = y_test

# predicted values

predicted = y_pred

# confusion matrix

matrix = confusion_matrix(actual,predicted, labels=[1,0],sample_weight=None, normalize=None)
print('Confusion matrix : \n', matrix)

# outcome values order in sklearn

tp, fn, fp, tn = confusion_matrix(actual,predicted,labels=[1,0]).reshape(-1)
print('Outcome values : \n', tp, fn, fp, tn)

# classification report for precision, recall f1-score and accuracy

C_Report = classification_report(actual,predicted,labels=[1,0])

print('Classification report : \n', C_Report)

# calculating the metrics

sensitivity = round(tp/(tp+fn), 3);
specificity = round(tn/(tn+fp), 3);
accuracy = round((tp+tn)/(tp+fp+tn+fn), 3);
balanced_accuracy = round((sensitivity+specificity)/2, 3);
precision = round(tp/(tp+fp), 3);
f1Score = round((2*tp/(2*tp + fp + fn)), 3);

# Matthews Correlation Coefficient (MCC). Range of values of MCC lie between -1 to +1. 
# A model with a score of +1 is a perfect model and -1 is a poor model

from math import sqrt

mx = (tp+fp) * (tp+fn) * (tn+fp) * (tn+fn)
MCC = round(((tp * tn) - (fp * fn)) / sqrt(mx), 3)

print('Accuracy :', round(accuracy*100, 2),'%')
print('Precision :', round(precision*100, 2),'%')
print('Recall :', round(sensitivity*100,2), '%')
print('F1 Score :', f1Score)
print('Specificity or True Negative Rate :', round(specificity*100,2), '%'  )
print('Balanced Accuracy :', round(balanced_accuracy*100, 2),'%')
print('MCC :', MCC)

# Area under ROC curve 

from sklearn.metrics import roc_curve, roc_auc_score

print('roc_auc_score:', round(roc_auc_score(y_test, y_pred), 3))

# ROC Curve

from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
logit_roc_auc = roc_auc_score(y_test, y_pred)
fpr, tpr, thresholds = roc_curve(y_test,ModelSVMGaussian.predict_proba(x_test)[:,1])
plt.figure()
# plt.plot
plt.plot(fpr, tpr, label= 'Classification Model' % logit_roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.savefig('Log_ROC')
plt.show() 
new_row = {'Model Name' : "SVM - Gaussian",
            'True_Positive' : tp, 
            'False_Negative' : fn, 
            'False_Positive' : fp,
            'True_Negative' : tn,
            'Accuracy' : accuracy,
            'Precision' : precision,
            'Recall' : sensitivity,
            'F1 Score' : f1Score,
            'Specificity' : specificity,
            'MCC':MCC,
            'ROC_AUC_Score':roc_auc_score(actual, predicted),
            'Balanced Accuracy':balanced_accuracy}
SVMResults = SVMResults.append(new_row, ignore_index=True)
#-----------------------------------------------------------------------------------------------------------
# Out:
# Model Name:  SVM - Gaussian
# Confusion matrix :
#  [[ 167   24]
#  [ 383 1024]]
# Outcome values :
#  167 24 383 1024
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.30      0.87      0.45       191
#            0       0.98      0.73      0.83      1407
#
#     accuracy                           0.75      1598
#    macro avg       0.64      0.80      0.64      1598
# weighted avg       0.90      0.75      0.79      1598
#
# Accuracy : 74.5 %
# Precision : 30.4 %
# Recall : 87.4 %
# F1 Score : 0.451
# Specificity or True Negative Rate : 72.8 %
# Balanced Accuracy : 80.1 %
# MCC : 0.411
# roc_auc_score: 0.801

# %% [markdown]
# # Sigmoid Kernel

# %%
# Training the SVM algorithm

from sklearn.svm import SVC

ModelSVMSig = SVC(kernel='sigmoid', random_state = 42, class_weight='balanced', probability=True)

# Train the model

ModelSVMSig.fit(x_train, y_train)

# Predict the model with test data set

y_pred = ModelSVMSig.predict(x_test)
y_pred_prob = ModelSVMSig.predict_proba(x_test)

# Print the model name
    
print('Model Name: ', "SVM - Sigmoid")

# Confusion matrix in sklearn

from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# actual values

actual = y_test

# predicted values

predicted = y_pred

# confusion matrix

matrix = confusion_matrix(actual,predicted, labels=[1,0],sample_weight=None, normalize=None)
print('Confusion matrix : \n', matrix)

# outcome values order in sklearn

tp, fn, fp, tn = confusion_matrix(actual,predicted,labels=[1,0]).reshape(-1)
print('Outcome values : \n', tp, fn, fp, tn)

# classification report for precision, recall f1-score and accuracy

C_Report = classification_report(actual,predicted,labels=[1,0])

print('Classification report : \n', C_Report)

# calculating the metrics

sensitivity = round(tp/(tp+fn), 3);
specificity = round(tn/(tn+fp), 3);
accuracy = round((tp+tn)/(tp+fp+tn+fn), 3);
balanced_accuracy = round((sensitivity+specificity)/2, 3);
precision = round(tp/(tp+fp), 3);
f1Score = round((2*tp/(2*tp + fp + fn)), 3);

# Matthews Correlation Coefficient (MCC). Range of values of MCC lie between -1 to +1. 
# A model with a score of +1 is a perfect model and -1 is a poor model

from math import sqrt

mx = (tp+fp) * (tp+fn) * (tn+fp) * (tn+fn)
MCC = round(((tp * tn) - (fp * fn)) / sqrt(mx), 3)

print('Accuracy :', round(accuracy*100, 2),'%')
print('Precision :', round(precision*100, 2),'%')
print('Recall :', round(sensitivity*100,2), '%')
print('F1 Score :', f1Score)
print('Specificity or True Negative Rate :', round(specificity*100,2), '%'  )
print('Balanced Accuracy :', round(balanced_accuracy*100, 2),'%')
print('MCC :', MCC)

# Area under ROC curve 

from sklearn.metrics import roc_curve, roc_auc_score

print('roc_auc_score:', round(roc_auc_score(y_test, y_pred), 3))

# ROC Curve

from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
logit_roc_auc = roc_auc_score(y_test, y_pred)
fpr, tpr, thresholds = roc_curve(y_test,ModelSVMSig.predict_proba(x_test)[:,1])
plt.figure()
# plt.plot
plt.plot(fpr, tpr, label= 'Classification Model' % logit_roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.savefig('Log_ROC')
plt.show()
new_row = {'Model Name' : "SVM - Sigmoid",
            'True_Positive' : tp, 
            'False_Negative' : fn, 
            'False_Positive' : fp,
            'True_Negative' : tn,
            'Accuracy' : accuracy,
            'Precision' : precision,
            'Recall' : sensitivity,
            'F1 Score' : f1Score,
            'Specificity' : specificity,
            'MCC':MCC,
            'ROC_AUC_Score':roc_auc_score(actual, predicted),
            'Balanced Accuracy':balanced_accuracy}
SVMResults = SVMResults.append(new_row, ignore_index=True)
#-----------------------------------------------------------------------------------------------------------
# Out:
# Model Name:  SVM - Sigmoid
# Confusion matrix :
#  [[ 84 107]
#  [802 605]]
# Outcome values :
#  84 107 802 605
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.09      0.44      0.16       191
#            0       0.85      0.43      0.57      1407
#
#     accuracy                           0.43      1598
#    macro avg       0.47      0.43      0.36      1598
# weighted avg       0.76      0.43      0.52      1598
#
# Accuracy : 43.1 %
# Precision : 9.5 %
# Recall : 44.0 %
# F1 Score : 0.156
# Specificity or True Negative Rate : 43.0 %
# Balanced Accuracy : 43.5 %
# MCC : -0.085
# roc_auc_score: 0.435

# %%
#Display the results of SVM Algorithm
SVMResults
# Out:
#          Model Name True_Positive False_Negative False_Positive True_Negative  \
# 0      SVM - Linear             0            191              0          1407
# 1  SVM - Polynomial             0            191              0          1407
# 2    SVM - Gaussian           167             24            383          1024
# 3     SVM - Sigmoid            84            107            802           605
#
#    Accuracy  Precision  Recall  F1 Score  Specificity    MCC  ROC_AUC_Score  \
# 0     0.880        NaN   0.000     0.000        1.000    NaN       0.500000
# 1     0.880        NaN   0.000     0.000        1.000    NaN       0.500000
# 2     0.745      0.304   0.874     0.451        0.728  0.411       0.801068
# 3     0.431      0.095   0.440     0.156        0.430 -0.085       0.434892
#
#    Balanced Accuracy
# 0              0.500
# 1              0.500
# 2              0.801
# 3              0.435

# %%
#Load the result file for KNN
KNNResults=pd.read_csv(r"C:\Users\Dlc\Desktop\INTERNSHIP 26-07\PROJECT\KNN_Results.csv",header=0)
#Display the  first five records
KNNResults.head()
# Out:
# Empty DataFrame
# Columns: [Model Name, KNN K Value, True_Positive, False_Negative, False_Positive, True_Negative, Accuracy, Precision, Recall, F1 Score, Specificity, MCC, ROC_AUC_Score, Balanced Accuracy]
# Index: []

# %% [markdown]
# # KNN Algorithm

# %%
# Bild KNN Model

from sklearn.neighbors import KNeighborsClassifier

from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

import sklearn.metrics as metrics

from sklearn.metrics import roc_curve, roc_auc_score

accuracy = []

for a in range(1, 21, 1):
    
    k = a
    
    # Build the model
    
    ModelKNN = KNeighborsClassifier(n_neighbors=k)
    
    # Train the model
    
    ModelKNN.fit(x_train, y_train)
    
    # Predict the model
    
    y_pred = ModelKNN.predict(x_test)
    y_pred_prob = ModelKNN.predict_proba(x_test)
    
    print('KNN_K_value = ', a)
    
    # Print the model name
    
    print('Model Name: ', ModelKNN)
    
    # confusion matrix in sklearn
    
    from sklearn.metrics import confusion_matrix
    from sklearn.metrics import classification_report
    
    # actual values
    
    actual = y_test
    
    # predicted values
    
    predicted = y_pred
    
    # confusion matrix
    
    matrix = confusion_matrix(actual,predicted, labels=[1,0],sample_weight=None, normalize=None)
    print('Confusion matrix : \n', matrix)
    
    # outcome values order in sklearn
    
    tp, fn, fp, tn = confusion_matrix(actual,predicted,labels=[1,0]).reshape(-1)
    print('Outcome values : \n', tp, fn, fp, tn)
    
    # classification report for precision, recall f1-score and accuracy
    
    C_Report = classification_report(actual,predicted,labels=[1,0])
    
    print('Classification report : \n', C_Report)
    
    # calculating the metrics
    
    sensitivity = round(tp/(tp+fn), 3);
    specificity = round(tn/(tn+fp), 3);
    accuracy = round((tp+tn)/(tp+fp+tn+fn), 3);
    balanced_accuracy = round((sensitivity+specificity)/2, 3);
    
    precision = round(tp/(tp+fp), 3);
    f1Score = round((2*tp/(2*tp + fp + fn)), 3);
    
    # Matthews Correlation Coefficient (MCC). Range of values of MCC lie between -1 to +1. 
    # A model with a score of +1 is a perfect model and -1 is a poor model
    
    from math import sqrt
    
    mx = (tp+fp) * (tp+fn) * (tn+fp) * (tn+fn)
    MCC = round(((tp * tn) - (fp * fn)) / sqrt(mx), 3)
    
    print('Accuracy :', round(accuracy*100, 2),'%')
    print('Precision :', round(precision*100, 2),'%')
    print('Recall :', round(sensitivity*100,2), '%')
    print('F1 Score :', f1Score)
    print('Specificity or True Negative Rate :', round(specificity*100,2), '%'  )
    print('Balanced Accuracy :', round(balanced_accuracy*100, 2),'%')
    print('MCC :', MCC)
    
    # Area under ROC curve 
    
    from sklearn.metrics import roc_curve, roc_auc_score
    
    print('roc_auc_score:', round(roc_auc_score(actual, predicted), 3))
    
    # ROC Curve
    
    from sklearn.metrics import roc_auc_score
    from sklearn.metrics import roc_curve
    model_roc_auc = roc_auc_score(actual, predicted)
    fpr, tpr, thresholds = roc_curve(actual, ModelKNN.predict_proba(x_test)[:,1])
    plt.figure()
    # plt.plot(fpr, tpr, label='Logistic Regression (area = %0.2f)' % logit_roc_auc)
    plt.plot(fpr, tpr, label= 'Classification Model' % model_roc_auc)
    plt.plot([0, 1], [0, 1],'r--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver operating characteristic')
    plt.legend(loc="lower right")
    #plt.savefig('Log_ROC')
    plt.show()
    new_row = {'Model Name' : ModelKNN,
               'KNN K Value' : a,
               'True_Positive' : tp,
               'False_Negative' : fn,
               'False_Positive' : fp,
               'True_Negative' : tn,
               'Accuracy' : accuracy,
               'Precision' : precision,
               'Recall' : sensitivity,
               'F1 Score' : f1Score,
               'Specificity' : specificity,
               'MCC':MCC,
               'ROC_AUC_Score':roc_auc_score(actual, predicted),
               'Balanced Accuracy':balanced_accuracy}
    KNNResults = KNNResults.append(new_row, ignore_index=True)
# Out:
# KNN_K_value =  1
# Model Name:  KNeighborsClassifier(n_neighbors=1)
# Confusion matrix :
#  [[ 138   53]
#  [  77 1330]]
# Outcome values :
#  138 53 77 1330
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.64      0.72      0.68       191
#            0       0.96      0.95      0.95      1407
#
#     accuracy                           0.92      1598
#    macro avg       0.80      0.83      0.82      1598
# weighted avg       0.92      0.92      0.92      1598
#
# Accuracy : 91.9 %
# Precision : 64.2 %
# Recall : 72.3 %
# F1 Score : 0.68
# Specificity or True Negative Rate : 94.5 %
# Balanced Accuracy : 83.4 %
# MCC : 0.635
# roc_auc_score: 0.834
# KNN_K_value =  2
# Model Name:  KNeighborsClassifier(n_neighbors=2)
# Confusion matrix :
#  [[  79  112]
#  [  47 1360]]
# Outcome values :
#  79 112 47 1360
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.63      0.41      0.50       191
#            0       0.92      0.97      0.94      1407
#
#     accuracy                           0.90      1598
#    macro avg       0.78      0.69      0.72      1598
# weighted avg       0.89      0.90      0.89      1598
#
# Accuracy : 90.1 %
# Precision : 62.7 %
# Recall : 41.4 %
# F1 Score : 0.498
# Specificity or True Negative Rate : 96.7 %
# Balanced Accuracy : 69.0 %
# MCC : 0.458
# roc_auc_score: 0.69
# KNN_K_value =  3
# Model Name:  KNeighborsClassifier(n_neighbors=3)
# Confusion matrix :
#  [[  87  104]
#  [  87 1320]]
# Outcome values :
#  87 104 87 1320
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.50      0.46      0.48       191
#            0       0.93      0.94      0.93      1407
#
#     accuracy                           0.88      1598
#    macro avg       0.71      0.70      0.70      1598
# weighted avg       0.88      0.88      0.88      1598
#
# Accuracy : 88.0 %
# Precision : 50.0 %
# Recall : 45.5 %
# F1 Score : 0.477
# Specificity or True Negative Rate : 93.8 %
# Balanced Accuracy : 69.6 %
# MCC : 0.41
# roc_auc_score: 0.697
# KNN_K_value =  4
# Model Name:  KNeighborsClassifier(n_neighbors=4)
# Confusion matrix :
#  [[  45  146]
#  [  42 1365]]
# Outcome values :
#  45 146 42 1365
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.52      0.24      0.32       191
#            0       0.90      0.97      0.94      1407
#
#     accuracy                           0.88      1598
#    macro avg       0.71      0.60      0.63      1598
# weighted avg       0.86      0.88      0.86      1598
#
# Accuracy : 88.2 %
# Precision : 51.7 %
# Recall : 23.6 %
# F1 Score : 0.324
# Specificity or True Negative Rate : 97.0 %
# Balanced Accuracy : 60.3 %
# MCC : 0.294
# roc_auc_score: 0.603
# KNN_K_value =  5
# Model Name:  KNeighborsClassifier()
# Confusion matrix :
#  [[  63  128]
#  [  68 1339]]
# Outcome values :
#  63 128 68 1339
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.48      0.33      0.39       191
#            0       0.91      0.95      0.93      1407
#
#     accuracy                           0.88      1598
#    macro avg       0.70      0.64      0.66      1598
# weighted avg       0.86      0.88      0.87      1598
#
# Accuracy : 87.7 %
# Precision : 48.1 %
# Recall : 33.0 %
# F1 Score : 0.391
# Specificity or True Negative Rate : 95.2 %
# Balanced Accuracy : 64.1 %
# MCC : 0.333
# roc_auc_score: 0.641
# KNN_K_value =  6
# Model Name:  KNeighborsClassifier(n_neighbors=6)
# Confusion matrix :
#  [[  44  147]
#  [  36 1371]]
# Outcome values :
#  44 147 36 1371
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.55      0.23      0.32       191
#            0       0.90      0.97      0.94      1407
#
#     accuracy                           0.89      1598
#    macro avg       0.73      0.60      0.63      1598
# weighted avg       0.86      0.89      0.86      1598
#
# Accuracy : 88.5 %
# Precision : 55.0 %
# Recall : 23.0 %
# F1 Score : 0.325
# Specificity or True Negative Rate : 97.4 %
# Balanced Accuracy : 60.2 %
# MCC : 0.305
# roc_auc_score: 0.602
# KNN_K_value =  7
# Model Name:  KNeighborsClassifier(n_neighbors=7)
# Confusion matrix :
#  [[  53  138]
#  [  43 1364]]
# Outcome values :
#  53 138 43 1364
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.55      0.28      0.37       191
#            0       0.91      0.97      0.94      1407
#
#     accuracy                           0.89      1598
#    macro avg       0.73      0.62      0.65      1598
# weighted avg       0.87      0.89      0.87      1598
#
# Accuracy : 88.7 %
# Precision : 55.2 %
# Recall : 27.7 %
# F1 Score : 0.369
# Specificity or True Negative Rate : 96.9 %
# Balanced Accuracy : 62.3 %
# MCC : 0.337
# roc_auc_score: 0.623
# KNN_K_value =  8
# Model Name:  KNeighborsClassifier(n_neighbors=8)
# Confusion matrix :
#  [[  35  156]
#  [  29 1378]]
# Outcome values :
#  35 156 29 1378
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.55      0.18      0.27       191
#            0       0.90      0.98      0.94      1407
#
#     accuracy                           0.88      1598
#    macro avg       0.72      0.58      0.61      1598
# weighted avg       0.86      0.88      0.86      1598
#
# Accuracy : 88.4 %
# Precision : 54.7 %
# Recall : 18.3 %
# F1 Score : 0.275
# Specificity or True Negative Rate : 97.9 %
# Balanced Accuracy : 58.1 %
# MCC : 0.269
# roc_auc_score: 0.581
# KNN_K_value =  9
# Model Name:  KNeighborsClassifier(n_neighbors=9)
# Confusion matrix :
#  [[  39  152]
#  [  42 1365]]
# Outcome values :
#  39 152 42 1365
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.48      0.20      0.29       191
#            0       0.90      0.97      0.93      1407
#
#     accuracy                           0.88      1598
#    macro avg       0.69      0.59      0.61      1598
# weighted avg       0.85      0.88      0.86      1598
#
# Accuracy : 87.9 %
# Precision : 48.1 %
# Recall : 20.4 %
# F1 Score : 0.287
# Specificity or True Negative Rate : 97.0 %
# Balanced Accuracy : 58.7 %
# MCC : 0.258
# roc_auc_score: 0.587
# KNN_K_value =  10
# Model Name:  KNeighborsClassifier(n_neighbors=10)
# Confusion matrix :
#  [[  24  167]
#  [  30 1377]]
# Outcome values :
#  24 167 30 1377
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.44      0.13      0.20       191
#            0       0.89      0.98      0.93      1407
#
#     accuracy                           0.88      1598
#    macro avg       0.67      0.55      0.56      1598
# weighted avg       0.84      0.88      0.85      1598
#
# Accuracy : 87.7 %
# Precision : 44.4 %
# Recall : 12.6 %
# F1 Score : 0.196
# Specificity or True Negative Rate : 97.9 %
# Balanced Accuracy : 55.2 %
# MCC : 0.187
# roc_auc_score: 0.552
# KNN_K_value =  11
# Model Name:  KNeighborsClassifier(n_neighbors=11)
# Confusion matrix :
#  [[  33  158]
#  [  40 1367]]
# Outcome values :
#  33 158 40 1367
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.45      0.17      0.25       191
#            0       0.90      0.97      0.93      1407
#
#     accuracy                           0.88      1598
#    macro avg       0.67      0.57      0.59      1598
# weighted avg       0.84      0.88      0.85      1598
#
# Accuracy : 87.6 %
# Precision : 45.2 %
# Recall : 17.3 %
# F1 Score : 0.25
# Specificity or True Negative Rate : 97.2 %
# Balanced Accuracy : 57.2 %
# MCC : 0.224
# roc_auc_score: 0.572
# KNN_K_value =  12
# Model Name:  KNeighborsClassifier(n_neighbors=12)
# Confusion matrix :
#  [[  24  167]
#  [  26 1381]]
# Outcome values :
#  24 167 26 1381
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.48      0.13      0.20       191
#            0       0.89      0.98      0.93      1407
#
#     accuracy                           0.88      1598
#    macro avg       0.69      0.55      0.57      1598
# weighted avg       0.84      0.88      0.85      1598
#
# Accuracy : 87.9 %
# Precision : 48.0 %
# Recall : 12.6 %
# F1 Score : 0.199
# Specificity or True Negative Rate : 98.2 %
# Balanced Accuracy : 55.4 %
# MCC : 0.2
# roc_auc_score: 0.554
# KNN_K_value =  13
# Model Name:  KNeighborsClassifier(n_neighbors=13)
# Confusion matrix :
#  [[  26  165]
#  [  33 1374]]
# Outcome values :
#  26 165 33 1374
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.44      0.14      0.21       191
#            0       0.89      0.98      0.93      1407
#
#     accuracy                           0.88      1598
#    macro avg       0.67      0.56      0.57      1598
# weighted avg       0.84      0.88      0.85      1598
#
# Accuracy : 87.6 %
# Precision : 44.1 %
# Recall : 13.6 %
# F1 Score : 0.208
# Specificity or True Negative Rate : 97.7 %
# Balanced Accuracy : 55.6 %
# MCC : 0.194
# roc_auc_score: 0.556
# KNN_K_value =  14
# Model Name:  KNeighborsClassifier(n_neighbors=14)
# Confusion matrix :
#  [[  19  172]
#  [  18 1389]]
# Outcome values :
#  19 172 18 1389
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.51      0.10      0.17       191
#            0       0.89      0.99      0.94      1407
#
#     accuracy                           0.88      1598
#    macro avg       0.70      0.54      0.55      1598
# weighted avg       0.84      0.88      0.84      1598
#
# Accuracy : 88.1 %
# Precision : 51.4 %
# Recall : 9.9 %
# F1 Score : 0.167
# Specificity or True Negative Rate : 98.7 %
# Balanced Accuracy : 54.3 %
# MCC : 0.187
# roc_auc_score: 0.543
# KNN_K_value =  15
# Model Name:  KNeighborsClassifier(n_neighbors=15)
# Confusion matrix :
#  [[  23  168]
#  [  27 1380]]
# Outcome values :
#  23 168 27 1380
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.46      0.12      0.19       191
#            0       0.89      0.98      0.93      1407
#
#     accuracy                           0.88      1598
#    macro avg       0.68      0.55      0.56      1598
# weighted avg       0.84      0.88      0.85      1598
#
# Accuracy : 87.8 %
# Precision : 46.0 %
# Recall : 12.0 %
# F1 Score : 0.191
# Specificity or True Negative Rate : 98.1 %
# Balanced Accuracy : 55.0 %
# MCC : 0.189
# roc_auc_score: 0.551
# KNN_K_value =  16
# Model Name:  KNeighborsClassifier(n_neighbors=16)
# Confusion matrix :
#  [[  17  174]
#  [  16 1391]]
# Outcome values :
#  17 174 16 1391
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.52      0.09      0.15       191
#            0       0.89      0.99      0.94      1407
#
#     accuracy                           0.88      1598
#    macro avg       0.70      0.54      0.54      1598
# weighted avg       0.84      0.88      0.84      1598
#
# Accuracy : 88.1 %
# Precision : 51.5 %
# Recall : 8.9 %
# F1 Score : 0.152
# Specificity or True Negative Rate : 98.9 %
# Balanced Accuracy : 53.9 %
# MCC : 0.177
# roc_auc_score: 0.539
# KNN_K_value =  17
# Model Name:  KNeighborsClassifier(n_neighbors=17)
# Confusion matrix :
#  [[  19  172]
#  [  19 1388]]
# Outcome values :
#  19 172 19 1388
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.50      0.10      0.17       191
#            0       0.89      0.99      0.94      1407
#
#     accuracy                           0.88      1598
#    macro avg       0.69      0.54      0.55      1598
# weighted avg       0.84      0.88      0.84      1598
#
# Accuracy : 88.0 %
# Precision : 50.0 %
# Recall : 9.9 %
# F1 Score : 0.166
# Specificity or True Negative Rate : 98.6 %
# Balanced Accuracy : 54.2 %
# MCC : 0.183
# roc_auc_score: 0.543
# KNN_K_value =  18
# Model Name:  KNeighborsClassifier(n_neighbors=18)
# Confusion matrix :
#  [[  16  175]
#  [  15 1392]]
# Outcome values :
#  16 175 15 1392
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.52      0.08      0.14       191
#            0       0.89      0.99      0.94      1407
#
#     accuracy                           0.88      1598
#    macro avg       0.70      0.54      0.54      1598
# weighted avg       0.84      0.88      0.84      1598
#
# Accuracy : 88.1 %
# Precision : 51.6 %
# Recall : 8.4 %
# F1 Score : 0.144
# Specificity or True Negative Rate : 98.9 %
# Balanced Accuracy : 53.6 %
# MCC : 0.172
# roc_auc_score: 0.537
# KNN_K_value =  19
# Model Name:  KNeighborsClassifier(n_neighbors=19)
# Confusion matrix :
#  [[  18  173]
#  [  16 1391]]
# Outcome values :
#  18 173 16 1391
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.53      0.09      0.16       191
#            0       0.89      0.99      0.94      1407
#
#     accuracy                           0.88      1598
#    macro avg       0.71      0.54      0.55      1598
# weighted avg       0.85      0.88      0.84      1598
#
# Accuracy : 88.2 %
# Precision : 52.9 %
# Recall : 9.4 %
# F1 Score : 0.16
# Specificity or True Negative Rate : 98.9 %
# Balanced Accuracy : 54.2 %
# MCC : 0.186
# roc_auc_score: 0.541
# KNN_K_value =  20
# Model Name:  KNeighborsClassifier(n_neighbors=20)
# Confusion matrix :
#  [[  10  181]
#  [  10 1397]]
# Outcome values :
#  10 181 10 1397
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.50      0.05      0.09       191
#            0       0.89      0.99      0.94      1407
#
#     accuracy                           0.88      1598
#    macro avg       0.69      0.52      0.52      1598
# weighted avg       0.84      0.88      0.84      1598
#
# Accuracy : 88.0 %
# Precision : 50.0 %
# Recall : 5.2 %
# F1 Score : 0.095
# Specificity or True Negative Rate : 99.3 %
# Balanced Accuracy : 52.2 %
# MCC : 0.132
# roc_auc_score: 0.523

# %%
#Display the results of KNN Algorithm
KNNResults
# Out:
#                               Model Name KNN K Value True_Positive  \
# 0    KNeighborsClassifier(n_neighbors=1)           1           138
# 1    KNeighborsClassifier(n_neighbors=2)           2            79
# 2    KNeighborsClassifier(n_neighbors=3)           3            87
# 3    KNeighborsClassifier(n_neighbors=4)           4            45
# 4                 KNeighborsClassifier()           5            63
# 5    KNeighborsClassifier(n_neighbors=6)           6            44
# 6    KNeighborsClassifier(n_neighbors=7)           7            53
# 7    KNeighborsClassifier(n_neighbors=8)           8            35
# 8    KNeighborsClassifier(n_neighbors=9)           9            39
# 9   KNeighborsClassifier(n_neighbors=10)          10            24
# 10  KNeighborsClassifier(n_neighbors=11)          11            33
# 11  KNeighborsClassifier(n_neighbors=12)          12            24
# 12  KNeighborsClassifier(n_neighbors=13)          13            26
# 13  KNeighborsClassifier(n_neighbors=14)          14            19
# 14  KNeighborsClassifier(n_neighbors=15)          15            23
# 15  KNeighborsClassifier(n_neighbors=16)          16            17
# 16  KNeighborsClassifier(n_neighbors=17)          17            19
# 17  KNeighborsClassifier(n_neighbors=18)          18            16
# 18  KNeighborsClassifier(n_neighbors=19)          19            18
# 19  KNeighborsClassifier(n_neighbors=20)          20            10
#
#    False_Negative False_Positive True_Negative  Accuracy  Precision  Recall  \
# 0              53             77          1330     0.919      0.642   0.723
# 1             112             47          1360     0.901      0.627   0.414
# 2             104             87          1320     0.880      0.500   0.455
# 3             146             42          1365     0.882      0.517   0.236
# 4             128             68          1339     0.877      0.481   0.330
# 5             147             36          1371     0.885      0.550   0.230
# 6             138             43          1364     0.887      0.552   0.277
# 7             156             29          1378     0.884      0.547   0.183
# 8             152             42          1365     0.879      0.481   0.204
# 9             167             30          1377     0.877      0.444   0.126
# 10            158             40          1367     0.876      0.452   0.173
# 11            167             26          1381     0.879      0.480   0.126
# 12            165             33          1374     0.876      0.441   0.136
# 13            172             18          1389     0.881      0.514   0.099
# 14            168             27          1380     0.878      0.460   0.120
# 15            174             16          1391     0.881      0.515   0.089
# 16            172             19          1388     0.880      0.500   0.099
# 17            175             15          1392     0.881      0.516   0.084
# 18            173             16          1391     0.882      0.529   0.094
# 19            181             10          1397     0.880      0.500   0.052
#
#     F1 Score  Specificity    MCC  ROC_AUC_Score  Balanced Accuracy
# 0      0.680        0.945  0.635       0.833893              0.834
# 1      0.498        0.967  0.458       0.690104              0.690
# 2      0.477        0.938  0.410       0.696832              0.696
# 3      0.324        0.970  0.294       0.602876              0.603
# 4      0.391        0.952  0.333       0.640757              0.641
# 5      0.325        0.974  0.305       0.602390              0.602
# 6      0.369        0.969  0.337       0.623463              0.623
# 7      0.275        0.979  0.269       0.581317              0.581
# 8      0.287        0.970  0.258       0.587169              0.587
# 9      0.196        0.979  0.187       0.552166              0.552
# 10     0.250        0.972  0.224       0.572173              0.572
# 11     0.199        0.982  0.200       0.553588              0.554
# 12     0.208        0.977  0.194       0.556336              0.556
# 13     0.167        0.987  0.187       0.543342              0.543
# 14     0.191        0.981  0.189       0.550615              0.550
# 15     0.152        0.989  0.177       0.538817              0.539
# 16     0.166        0.986  0.183       0.542986              0.542
# 17     0.144        0.989  0.172       0.536554              0.536
# 18     0.160        0.989  0.186       0.541435              0.542
# 19     0.095        0.993  0.132       0.522624              0.522

# %% [markdown]
# # Compare the classification Algorithms

# %%
# Load the results file for classification
EMResults = pd.read_csv(r"C:\Users\Dlc\Desktop\INTERNSHIP 26-07\PROJECT\EMResults.csv",header=0)
EMResults.head()
# Out:
# Empty DataFrame
# Columns: [Model Name, True_Positive, False_Negative, False_Positive, True_Negative, Accuracy, Precision, Recall, F1 Score, Specificity, MCC, ROC_AUC_Score, Balanced Accuracy]
# Index: []

# %%
# Build the Calssification models and compare the results

from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC

# Create objects of classification algorithms with default hyper-parameters

ModelLR = LogisticRegression()
ModelDC = DecisionTreeClassifier()
ModelRF = RandomForestClassifier()
ModelET = ExtraTreesClassifier()
ModelKNN = KNeighborsClassifier(n_neighbors=5)
ModelGNB = GaussianNB()
ModelSVM = SVC(kernel='linear', random_state = 42, class_weight='balanced', probability=True)

# Evalution matrix for all the algorithms

MM = [ModelLR, ModelDC, ModelRF, ModelET, ModelKNN, ModelGNB, ModelSVM]
#MM = [ModelLR, ModelDC, ModelRF, ModelET]
for models in MM:
            
    # Train the model training dataset
    
    models.fit(x_train, y_train)
    
    # Prediction the model with test dataset
    
    y_pred = models.predict(x_test)
    y_pred_prob = models.predict_proba(x_test)
    
    # Print the model name
    
    print('Model Name: ', models)
    
    # confusion matrix in sklearn

    from sklearn.metrics import confusion_matrix
    from sklearn.metrics import classification_report

    # actual values

    actual = y_test

    # predicted values

    predicted = y_pred

    # confusion matrix

    matrix = confusion_matrix(actual,predicted, labels=[1,0],sample_weight=None, normalize=None)
    print('Confusion matrix : \n', matrix)

    # outcome values order in sklearn

    tp, fn, fp, tn = confusion_matrix(actual,predicted,labels=[1,0]).reshape(-1)
    print('Outcome values : \n', tp, fn, fp, tn)

    # classification report for precision, recall f1-score and accuracy

    C_Report = classification_report(actual,predicted,labels=[1,0])

    print('Classification report : \n', C_Report)

    # calculating the metrics

    sensitivity = round(tp/(tp+fn), 3);
    specificity = round(tn/(tn+fp), 3);
    accuracy = round((tp+tn)/(tp+fp+tn+fn), 3);
    balanced_accuracy = round((sensitivity+specificity)/2, 3);
    
    precision = round(tp/(tp+fp), 3);
    f1Score = round((2*tp/(2*tp + fp + fn)), 3);

    # Matthews Correlation Coefficient (MCC). Range of values of MCC lie between -1 to +1. 
    # A model with a score of +1 is a perfect model and -1 is a poor model

    from math import sqrt

    mx = (tp+fp) * (tp+fn) * (tn+fp) * (tn+fn)
    MCC = round(((tp * tn) - (fp * fn)) / sqrt(mx), 3)

    print('Accuracy :', round(accuracy*100, 2),'%')
    print('Precision :', round(precision*100, 2),'%')
    print('Recall :', round(sensitivity*100,2), '%')
    print('F1 Score :', f1Score)
    print('Specificity or True Negative Rate :', round(specificity*100,2), '%'  )
    print('Balanced Accuracy :', round(balanced_accuracy*100, 2),'%')
    print('MCC :', MCC)

    # Area under ROC curve 

    from sklearn.metrics import roc_curve, roc_auc_score

    print('roc_auc_score:', round(roc_auc_score(actual, predicted), 3))
    
    # ROC Curve
    
    from sklearn.metrics import roc_auc_score
    from sklearn.metrics import roc_curve
    Model_roc_auc = roc_auc_score(actual, predicted)
    fpr, tpr, thresholds = roc_curve(actual, models.predict_proba(x_test)[:,1])
    plt.figure()
    #
    plt.plot(fpr, tpr, label= 'Classification Model' % Model_roc_auc)
    plt.plot([0, 1], [0, 1],'r--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver operating characteristic')
    plt.legend(loc="lower right")
    plt.savefig('Log_ROC')
    plt.show()
    print('-----------------------------------------------------------------------------------------------------')
    #----------------------------------------------------------------------------------------------------------
    new_row = {'Model Name' : models,
               'True_Positive': tp,
               'False_Negative': fn, 
               'False_Positive': fp, 
               'True_Negative': tn,
               'Accuracy' : accuracy,
               'Precision' : precision,
               'Recall' : sensitivity,
               'F1 Score' : f1Score,
               'Specificity' : specificity,
               'MCC':MCC,
               'ROC_AUC_Score':roc_auc_score(actual, predicted),
               'Balanced Accuracy':balanced_accuracy}
    EMResults = EMResults.append(new_row, ignore_index=True)
    #----------------------------------------------------------------------------------------------------------
#======================================================================================================================>
# Out:
# Model Name:  LogisticRegression()
# Confusion matrix :
#  [[  19  172]
#  [   9 1398]]
# Outcome values :
#  19 172 9 1398
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.68      0.10      0.17       191
#            0       0.89      0.99      0.94      1407
#
#     accuracy                           0.89      1598
#    macro avg       0.78      0.55      0.56      1598
# weighted avg       0.87      0.89      0.85      1598
#
# Accuracy : 88.7 %
# Precision : 67.9 %
# Recall : 9.9 %
# F1 Score : 0.174
# Specificity or True Negative Rate : 99.4 %
# Balanced Accuracy : 54.6 %
# MCC : 0.23
# roc_auc_score: 0.547
# -----------------------------------------------------------------------------------------------------
# Model Name:  DecisionTreeClassifier()
# Confusion matrix :
#  [[ 136   55]
#  [  72 1335]]
# Outcome values :
#  136 55 72 1335
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.65      0.71      0.68       191
#            0       0.96      0.95      0.95      1407
#
#     accuracy                           0.92      1598
#    macro avg       0.81      0.83      0.82      1598
# weighted avg       0.92      0.92      0.92      1598
#
# Accuracy : 92.1 %
# Precision : 65.4 %
# Recall : 71.2 %
# F1 Score : 0.682
# Specificity or True Negative Rate : 94.9 %
# Balanced Accuracy : 83.0 %
# MCC : 0.637
# roc_auc_score: 0.83
# -----------------------------------------------------------------------------------------------------
# Model Name:  RandomForestClassifier()
# Confusion matrix :
#  [[ 134   57]
#  [   9 1398]]
# Outcome values :
#  134 57 9 1398
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.94      0.70      0.80       191
#            0       0.96      0.99      0.98      1407
#
#     accuracy                           0.96      1598
#    macro avg       0.95      0.85      0.89      1598
# weighted avg       0.96      0.96      0.96      1598
#
# Accuracy : 95.9 %
# Precision : 93.7 %
# Recall : 70.2 %
# F1 Score : 0.802
# Specificity or True Negative Rate : 99.4 %
# Balanced Accuracy : 84.8 %
# MCC : 0.79
# roc_auc_score: 0.848
# -----------------------------------------------------------------------------------------------------
# Model Name:  ExtraTreesClassifier()
# Confusion matrix :
#  [[ 136   55]
#  [  17 1390]]
# Outcome values :
#  136 55 17 1390
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.89      0.71      0.79       191
#            0       0.96      0.99      0.97      1407
#
#     accuracy                           0.95      1598
#    macro avg       0.93      0.85      0.88      1598
# weighted avg       0.95      0.95      0.95      1598
#
# Accuracy : 95.5 %
# Precision : 88.9 %
# Recall : 71.2 %
# F1 Score : 0.791
# Specificity or True Negative Rate : 98.8 %
# Balanced Accuracy : 85.0 %
# MCC : 0.772
# roc_auc_score: 0.85
# -----------------------------------------------------------------------------------------------------
# Model Name:  KNeighborsClassifier()
# Confusion matrix :
#  [[  63  128]
#  [  68 1339]]
# Outcome values :
#  63 128 68 1339
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.48      0.33      0.39       191
#            0       0.91      0.95      0.93      1407
#
#     accuracy                           0.88      1598
#    macro avg       0.70      0.64      0.66      1598
# weighted avg       0.86      0.88      0.87      1598
#
# Accuracy : 87.7 %
# Precision : 48.1 %
# Recall : 33.0 %
# F1 Score : 0.391
# Specificity or True Negative Rate : 95.2 %
# Balanced Accuracy : 64.1 %
# MCC : 0.333
# roc_auc_score: 0.641
# -----------------------------------------------------------------------------------------------------
# Model Name:  GaussianNB()
# Confusion matrix :
#  [[  99   92]
#  [ 198 1209]]
# Outcome values :
#  99 92 198 1209
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.33      0.52      0.41       191
#            0       0.93      0.86      0.89      1407
#
#     accuracy                           0.82      1598
#    macro avg       0.63      0.69      0.65      1598
# weighted avg       0.86      0.82      0.83      1598
#
# Accuracy : 81.9 %
# Precision : 33.3 %
# Recall : 51.8 %
# F1 Score : 0.406
# Specificity or True Negative Rate : 85.9 %
# Balanced Accuracy : 68.8 %
# MCC : 0.315
# roc_auc_score: 0.689
# -----------------------------------------------------------------------------------------------------
# Model Name:  SVC(class_weight='balanced', kernel='linear', probability=True, random_state=42)
# Confusion matrix :
#  [[ 158   33]
#  [ 384 1023]]
# Outcome values :
#  158 33 384 1023
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.29      0.83      0.43       191
#            0       0.97      0.73      0.83      1407
#
#     accuracy                           0.74      1598
#    macro avg       0.63      0.78      0.63      1598
# weighted avg       0.89      0.74      0.78      1598
#
# Accuracy : 73.9 %
# Precision : 29.2 %
# Recall : 82.7 %
# F1 Score : 0.431
# Specificity or True Negative Rate : 72.7 %
# Balanced Accuracy : 77.7 %
# MCC : 0.38
# roc_auc_score: 0.777
# -----------------------------------------------------------------------------------------------------

# %%
EMResults.head(10)
# Out:
#                                           Model Name True_Positive  \
# 0                               LogisticRegression()            19
# 1                           DecisionTreeClassifier()           136
# 2  (DecisionTreeClassifier(max_features='sqrt', r...           134
# 3  (ExtraTreeClassifier(random_state=1579627319),...           136
# 4                             KNeighborsClassifier()            63
# 5                                       GaussianNB()            99
# 6  SVC(class_weight='balanced', kernel='linear', ...           158
#
#   False_Negative False_Positive True_Negative  Accuracy  Precision  Recall  \
# 0            172              9          1398     0.887      0.679   0.099
# 1             55             72          1335     0.921      0.654   0.712
# 2             57              9          1398     0.959      0.937   0.702
# 3             55             17          1390     0.955      0.889   0.712
# 4            128             68          1339     0.877      0.481   0.330
# 5             92            198          1209     0.819      0.333   0.518
# 6             33            384          1023     0.739      0.292   0.827
#
#    F1 Score  Specificity    MCC  ROC_AUC_Score  Balanced Accuracy
# 0     0.174        0.994  0.230       0.546540              0.546
# 1     0.682        0.949  0.637       0.830435              0.830
# 2     0.802        0.994  0.790       0.847587              0.848
# 3     0.791        0.988  0.772       0.849980              0.850
# 4     0.391        0.952  0.333       0.640757              0.641
# 5     0.406        0.859  0.315       0.688800              0.688
# 6     0.431        0.727  0.380       0.777152              0.777

# %%
# Assuming you have also predicted using DecisionTreeClassifier(Model RF)
# Since having more accuracy we have choosen it for prediction
y_pred1=ModelRF.predict(x_test)

# %%
# Display the Final results by data frame 

Results = pd.DataFrame({ 'stroke_A':y_test, 'stroke_P':y_pred})

# Merge two Dataframes on index of both the dataframes

ResultsFinal = pd.DataFrame({'stroke_A': y_test, 'stroke_P': y_pred})

#Display 10 records randomly 
ResultsFinal.sample(10)
# Out:
#       stroke_A  stroke_P
# 4198         0         0
# 4508         0         1
# 4988         1         1
# 1808         0         1
# 4694         0         0
# 999          0         0
# 1231         0         0
# 4638         0         0
# 4775         0         0
# 5086         1         1

# %%
# Display the Final results by merging duplicate file

Results=pd.DataFrame({'stroke_A':y_test,'stroke_P':y_pred1})

# Merge two Dataframes on index of both the dataframes

ResultsFinal=bsdata_bk.merge(Results,left_index=True,right_index=True)

#Display 10 records randomly

ResultsFinal.sample(10)
# Out:
#       gender    age  hypertension  heart_disease ever_married      work_type  \
# 3473  Female  73.00             0              0          Yes  Self-employed
# 2714    Male   1.64             0              0           No       children
# 4278  Female  46.00             0              0          Yes       Govt_job
# 3478    Male  71.00             0              0          Yes       Govt_job
# 734   Female  40.00             0              0          Yes       Govt_job
# 1374  Female  30.00             0              0          Yes        Private
# 4718    Male  33.00             0              0          Yes       Govt_job
# 2042  Female  41.00             0              0          Yes  Self-employed
# 1859    Male  11.00             0              0           No       children
# 1101  Female  33.00             0              0          Yes        Private
#
#      Residence_type  avg_glucose_level   bmi   smoking_status  stroke  \
# 3473          Rural              98.69  27.6          Unknown       0
# 2714          Urban             170.88  20.8          Unknown       0
# 4278          Rural              76.43  22.7          Unknown       0
# 3478          Rural              99.76  33.4  formerly smoked       0
# 734           Urban             122.74  23.3          Unknown       0
# 1374          Rural             124.08  41.1          Unknown       0
# 4718          Rural              81.10  24.8     never smoked       0
# 2042          Rural              89.14  37.4  formerly smoked       0
# 1859          Urban              99.79  20.2          Unknown       0
# 1101          Urban              79.91  33.5     never smoked       0
#
#       stroke_A  stroke_P
# 3473         0         0
# 2714         0         0
# 4278         0         0
# 3478         0         0
# 734          0         0
# 1374         0         0
# 4718         0         0
# 2042         0         0
# 1859         0         0
# 1101         0         0
